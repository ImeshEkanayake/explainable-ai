# %%
import os
import h5py
import json
import keras
import random 
import imageio
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn import tree
from keras import backend as K
from datetime import timedelta
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
# Out:
# Using TensorFlow backend.

# %%
Data = pd.read_csv('DsDnsPrScTch.csv')
# Out:
# C:\Users\REDLINE PC\.conda\envs\Laptop\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Data["Teacher First Project Posted Date"]=pd.to_datetime(Data["Teacher First Project Posted Date"])
Data["Project Fully Funded Date"]=pd.to_datetime(Data["Project Fully Funded Date"])
Data["Project Expiration Date"]=pd.to_datetime(Data["Project Expiration Date"])
Data["Project Posted Date"]=pd.to_datetime(Data["Project Posted Date"])
Data["Donation Received Date"]=pd.to_datetime(Data["Donation Received Date"])
Data["Number of dates since posted"]=Data.loc[:,"Donation Received Date"]-Data.loc[:,"Project Posted Date"]

# %%
# con Teacher Project Posted Sequence, Teacher Project Posted Sequence, Project Expiration Date, Teacher First Project Posted Date

# cat Project Type,Teacher Prefix, School State,School District

# %%
Data.dtypes
# Out:
# Unnamed: 0                                          int64
# Project ID                                         object
# Donation ID                                        object
# Donor ID                                           object
# Donation Included Optional Donation                object
# Donation Amount                                   float64
# Donor Cart Sequence                                 int64
# Donation Received Date                     datetime64[ns]
# Donor City                                         object
# Donor State                                        object
# Donor Is Teacher                                   object
# Donor Zip                                          object
# Unnamed: 0.1                                        int64
# School ID                                          object
# Teacher ID                                         object
# Teacher Project Posted Sequence                     int64
# Project Type                                       object
# Project Title                                      object
# Project Essay                                      object
# Project Short Description                          object
# Project Need Statement                             object
# Project Subject Category Tree                      object
# Project Subject Subcategory Tree                   object
# Project Grade Level Category                       object
# Project Resource Category                          object
# Project Cost                                      float64
# Project Posted Date                        datetime64[ns]
# Project Expiration Date                    datetime64[ns]
# Project Current Status                             object
# Project Fully Funded Date                  datetime64[ns]
# Project Short Description_polarity                float64
# Project Short Description_subjectivity            float64
# Project Essay_polarity                            float64
# Project Essay_subjectivity                        float64
# Project Need Statement_polarity                   float64
# Project Need Statement_subjectivity               float64
# School Name                                        object
# School Metro Type                                  object
# School Percentage Free Lunch                      float64
# School State                                       object
# School Zip                                        float64
# School City                                        object
# School County                                      object
# School District                                    object
# Teacher Prefix                                     object
# Teacher First Project Posted Date          datetime64[ns]
# Number of dates since posted              timedelta64[ns]
# dtype: object

# %%
T=pd.Timedelta('30 days')
sub_var=["Number of dates since posted","Project ID","Donation Amount","Project Cost",
         "Project Posted Date","Project Expiration Date","Donation Received Date","Project Short Description_polarity",
        "Project Short Description_subjectivity","Project Essay_polarity","Project Essay_subjectivity",
         "Project Need Statement_polarity","Project Need Statement_subjectivity"]
sub_Data =Data.loc[:,sub_var]
sub_Data=sub_Data[sub_Data["Number of dates since posted"] < T]
sub_Data["Raised funds to project cost ratio"]=sub_Data["Donation Amount"]/sub_Data["Project Cost"]
Grouped_data=sub_Data.groupby(["Project ID"]).sum()
Grouped_data_Final = sub_Data.groupby(["Project ID"]).max()
Grouped_data_Final["Raised funds to project cost ratio"]=Grouped_data["Raised funds to project cost ratio"]

f, axes = plt.subplots(1, 1,figsize=(10,7))

y="Raised funds to project cost ratio"
q1 = Grouped_data_Final[y].quantile(0)
q3 = Grouped_data_Final[y].quantile(1)
mask = Grouped_data_Final[y].between(q1, q3, inclusive=True)
iqr = Grouped_data_Final.loc[mask, y]
sns.distplot(iqr, ax=axes,axlabel=y )
print(iqr.describe())
# Out:
# C:\Users\REDLINE PC\.conda\envs\Laptop\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count    743945.000000
# mean          0.462287
# std           0.332363
# min           0.000030
# 25%           0.138487
# 50%           0.480108
# 75%           0.742170
# max           2.550013
# Name: Raised funds to project cost ratio, dtype: float64

# %%
T=pd.Timedelta('120 days')
sub_var=["Number of dates since posted","Project ID","Donation Amount","Project Cost",
         "Project Posted Date","Project Expiration Date","Donation Received Date","Project Short Description_polarity",
        "Project Short Description_subjectivity","Project Essay_polarity","Project Essay_subjectivity",
         "Project Need Statement_polarity","Project Need Statement_subjectivity"]
sub_Data =Data.loc[:,sub_var]
sub_Data=sub_Data[sub_Data["Number of dates since posted"] < T]
sub_Data["Raised funds to project cost ratio"]=sub_Data["Donation Amount"]/sub_Data["Project Cost"]
Grouped_data=sub_Data.groupby(["Project ID"]).sum()
Grouped_data_Final = sub_Data.groupby(["Project ID"]).max()
Grouped_data_Final["Raised funds to project cost ratio"]=Grouped_data["Raised funds to project cost ratio"]

f, axes = plt.subplots(1, 1,figsize=(10,7))

y="Raised funds to project cost ratio"
q1 = Grouped_data_Final[y].quantile(0)
q3 = Grouped_data_Final[y].quantile(1)
mask = Grouped_data_Final[y].between(q1, q3, inclusive=True)
iqr = Grouped_data_Final.loc[mask, y]
sns.distplot(iqr, ax=axes,axlabel=y )
print(iqr.describe())

G120=Grouped_data_Final
# Out:
# C:\Users\REDLINE PC\.conda\envs\Laptop\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count    870802.000000
# mean          0.555950
# std           0.337268
# min           0.000026
# 25%           0.255094
# 50%           0.500019
# 75%           0.889879
# max           2.550013
# Name: Raised funds to project cost ratio, dtype: float64

# %%
#===============================================================================================
#                                  Model Training Funstion
#===============================================================================================

def Train_Model(Classifier, Model_variables_con,Model_variables_cat,Data,
                Time_period_indays=30,K=100,Fund_Ratio_treshold=0.142):
    # Time_period should be in days 
    # K is the Top-K value

    #=================================== Initiate the List Variables ================================
    
    Time_points = []
    Output=dict()
    Output["Overall_Training_Accuracy"], Output["Overall_Training_Precision"], Output["Overall_Training_Recall"] = list(),list(),list()
    Output["Overall_Testing_Accuracy"], Output["Overall_Testing_Precision"], Output["Overall_Testing_Recall"] = list(),list(),list()
    Output["Top_K_Accuracy"], Output["Top_K_Precision"], Output["Top_K_Recall"] = list(),list(),list()

    #=================================== Initiate the Columns ======================================
    
    print("Initiatnig the Columns")
    Main_Variables = list(set(["Project ID","Project Posted Date","Project Expiration Date","Donation Received Date",
         "Project Cost","Donation Amount","Number of dates since posted"]+Model_variables_cat+Model_variables_con))
    Model_variables = Model_variables_con.copy()
    print("Variables considered in model training")
    for i in sub_var: print(">",i,i in Data.columns) # print all variables considered.
    print()
    Data["Number of dates since posted"]=Data.loc[:,"Donation Received Date"]-Data.loc[:,"Project Posted Date"]
    sub_Data = Data.loc[:,Main_Variables]
    

    #================================= One-Hot-Encoding Columns to remove ==========================
    
    print("One-Hot-Encoding removing columns identification")
    Sub_Variables_to_remove=dict()
    for i in Model_variables_cat:
        sub_variables = Data[i].unique()
        Model_variables+=sorted([i+"_"+str(j) for j in Data[i].unique()])
        Model_variables.remove(i+"_"+str(sub_variables[0]))
        Sub_Variables_to_remove[i]=sub_variables[0]
        
    
    #=================================== Initiate Time Variables ====================================
    
    print("Initiate Time Variables")
    MaxT = pd.Timestamp("2018-05-01 00:00:00")  #max(Data["Project Posted Date"])
    MinT = pd.Timestamp("2013-01-01 00:00:00")  #min(Data["Project Posted Date"])
    Time_period = timedelta(days=Time_period_indays)  
    T_current = MinT- Time_period +timedelta(days=120) 
    sub_Data["Number of dates since posted"] = sub_Data["Number of dates since posted"]/ np.timedelta64(1, 'D')
    
    
    #=================================== Loop over time frams =======================================
    
    print("Time iteration is starting\n")
    while (T_current<MaxT-Time_period):
        
        T_current = T_current+ Time_period
        Time_points+=[T_current]
        T_Train_start = T_current-timedelta(days=120)  # Start of the data frame
        T_Train_end = T_current-Time_period  #End of the data frame
        print("As of Date:",T_current,"\n"+"="*85)
        
    #====================================== Extract the frams ======================================= 
    
        # Extracts projects posted before the Current(As of) date
        Data_in_TimeWindow = sub_Data[sub_Data["Project Posted Date"] < pd.to_datetime(T_current)]  
        
        # Extracts projects posted after the start date of the Time window
        Data_in_TimeWindow = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] > pd.to_datetime(T_Train_start)]
        
        #Time period to be consided for the donations since posted (30days, as default)
        Data_in_TimeWindow = Data_in_TimeWindow[Data_in_TimeWindow["Number of dates since posted"]< Time_period_indays]
        
        #Express the donation amount as a ratio of to the Project cost
        Data_in_TimeWindow["Fund_Ratio"]=Data_in_TimeWindow["Donation Amount"]/Data_in_TimeWindow["Project Cost"]
        
        
    #=========================== Do One-Hot_Encoding for Categorical Variables ======================
    
        for var in Model_variables_cat:
            Sub_Dummied_Data=pd.get_dummies(Data_in_TimeWindow[var])  #create dummpy variables with one hot encoding 
            Sub_Dummied_Data_columns=sorted(Sub_Dummied_Data.columns)  #extract the column names of dummpy variables
            Sub_Dummied_Data_columns.remove(Sub_Variables_to_remove[var]) #remove a pre defined column from dummpy variables
            Data_in_TimeWindow=Data_in_TimeWindow.drop([var], axis=1) #remove main variable from the dataset
            #copy the columns to the main data set 
            for col in Sub_Dummied_Data_columns : Data_in_TimeWindow[var+"_"+col] = Sub_Dummied_Data[col]
                
        #Add the columns which have not been one-hot-encoded
        for i in Model_variables:
            if i not in Data_in_TimeWindow.columns:  Data_in_TimeWindow[i]=0
    
    
    #============================================ Imputing ==========================================
        Data_in_TimeWindow.fillna(Data_in_TimeWindow.median(), inplace=True)
                
    
    #=================================== Training set Creation =====================================
    
        #extract the training set from the timewindow
        Train_Data = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] < pd.to_datetime(T_Train_end)]
        
        #Group by Project ID
        Train_Data_CR=Train_Data.groupby(["Project ID"]).sum() 
        Train_Data_Final=Train_Data.groupby(["Project ID"]).max()
        Train_Data_Final["Fund_Ratio"]=Train_Data_CR["Fund_Ratio"]
        Train_Data_Final["Donation Amount"]=Train_Data_CR["Donation Amount"]
        
        # Define Fund_Ratio_Treshold
        Fund_Ratio_Treshold = Fund_Ratio_treshold
        Fund_Ratio_Treshold = Train_Data_Final["Fund_Ratio"].median()
        
        # Genarate the Label for the dataset 
        Train_Data_Final['Label'] = Train_Data_Final.apply(lambda x : 1  if x['Fund_Ratio'] < 
                                                           Fund_Ratio_Treshold  else 0, axis=1)
        
        X_train = Train_Data_Final.loc[:,Model_variables]
        Y_train = np.array(Train_Data_Final.loc[:,["Label"]])[:,0]
        
        
    #==================================== Testing set Creation =====================================
    
        #extract the training set from the timewindow
        Test_Data = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] >= pd.to_datetime(T_Train_end)]
        
        #Group by Project ID
        Test_Data_CR=Test_Data.groupby(["Project ID"]).sum() 
        Test_Data_Final=Test_Data.groupby(["Project ID"]).max()
        Test_Data_Final["Fund_Ratio"]=Test_Data_CR["Fund_Ratio"]
        Test_Data_Final["Donation Amount"]=Test_Data_CR["Donation Amount"]
        
        # Genarate the Label for the dataset 
        Test_Data_Final['Label'] = Test_Data_Final.apply(lambda x : 1  if x['Fund_Ratio'] < 
                                                         Fund_Ratio_Treshold  else 0, axis=1)
        X_test = Test_Data_Final.loc[:,Model_variables]
        Y_test = np.array(Test_Data_Final.loc[:,["Label"]])[:,0]
        
        
    #===================================== Model Training =========================================
    
        Classifier.fit(X_train, Y_train)
        
        # Predict on training 
        Train_Data_Final["Y_pred_prob"] = Classifier.predict_proba(X_train)[:,1]
        Train_Data_Final["Y_pred"]= Classifier.predict(X_train)
        # Predict on testing 
        Test_Data_Final["Y_pred_prob"] = Classifier.predict_proba(X_test)[:,1]
        Test_Data_Final["Y_pred"] = Classifier.predict(X_test)

        
    #====================================== Evaluation Trainign  ============================================
    
        Training_CM= confusion_matrix(Y_train,Train_Data_Final["Y_pred"])
        Training_TN, Training_FP ,Training_FN, Training_TP =  Training_CM.ravel()
        
        Training_Accuracy=(Training_TP+Training_TN)/(Training_TN+ Training_FP +Training_FN+ Training_TP)
        Training_Precision=Training_TP/(Training_TP+Training_FP)
        Training_Recall=Training_TP/(Training_TP+Training_FN)
        
        print(Classifier.__class__.__name__,' Testing Accuracy = ',Training_Accuracy)
        print("\tTraining_TP:",Training_TP,"\tTraining_FP:",Training_FP,
              "\n\tTraining_TN:",Training_TN,"\tTraining_FN:",Training_FN ,end="\n"*2)
        
        
    #====================================== Evaluation Testign  ============================================   
    
        Testing_CM= confusion_matrix(Y_test,Test_Data_Final["Y_pred"])
        Testing_TN, Testing_FP ,Testing_FN, Testing_TP =  Testing_CM.ravel()
        
        Testing_Accuracy=(Testing_TP+Testing_TN)/(Testing_TN+ Testing_FP +Testing_FN+ Testing_TP)
        Testing_Precision=Testing_TP/(Testing_TP+Testing_FP)
        Testing_Recall=Testing_TP/(Testing_TP+Testing_FN)
        
        print(Classifier.__class__.__name__,' Testing Accuracy = ',Testing_Accuracy)
        print("\tTesting_TP:",Testing_TP,"\tTesting_FP:",Testing_FP,
              "\n\tTesting_TN:",Testing_TN,"\tTesting_FN:",Testing_FN ,end="\n"*2)
        
    #====================================== Evaluation Top K  ============================================        
        
        Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
        Top_K=Test_Data_Final.head(K)
        Y_test_Top_K =  Top_K.loc[:,["Label"]] 
        Y_pred_Top_K =  Top_K.loc[:,["Y_pred"]]
        Testing_Top_K_CM= confusion_matrix(Y_test_Top_K,Y_pred_Top_K)
        if len(Testing_Top_K_CM.ravel())==4:
            Testing_Top_K_TN, Testing_Top_K_FP ,Testing_Top_K_FN, Testing_Top_K_TP =  Testing_Top_K_CM.ravel()
        else:
            Testing_Top_K_TN, Testing_Top_K_FP ,Testing_Top_K_FN, Testing_Top_K_TP=0,0,0,K
        
        Testing_Top_K_Accuracy=(Testing_Top_K_TP+Testing_Top_K_TN)/(Testing_Top_K_TN
                                                                        + Testing_Top_K_FP +Testing_Top_K_FN+ Testing_Top_K_TP)
        Testing_Top_K_Precision=Testing_Top_K_TP/(Testing_TP+Testing_FP)
        Testing_Top_K_Recall=Testing_Top_K_TP/(Testing_TP+Testing_FN)
        
        print(Classifier.__class__.__name__,' Testing Accuracy = ',Testing_Top_K_Accuracy)
        print("\tTesting_Top_K_TP:",Testing_Top_K_TP,"\tTesting_Top_K_FP:",Testing_Top_K_FP,
              "\n\tTesting_Top_K_TN:",Testing_Top_K_TN,"\tTesting_Top_K_FN:",Testing_Top_K_FN ,end="\n"*2)
        
     #====================================== save computed values  ============================================       
        Output["Overall_Training_Accuracy"] += [Training_Accuracy]
        Output["Overall_Training_Precision"] += [Training_Precision]
        Output["Overall_Training_Recall"] += [Training_Recall ]
        
        Output["Overall_Testing_Accuracy"] += [Testing_Accuracy]
        Output["Overall_Testing_Precision"] += [Testing_Precision]
        Output["Overall_Testing_Recall"] += [Testing_Recall]
        
        Output["Top_K_Accuracy"] += [Testing_Top_K_Accuracy] 
        Output["Top_K_Precision"] += [Testing_Top_K_Precision]  
        Output["Top_K_Recall"] += [Testing_Top_K_Recall] 
    
    
    Output["Classifier"]=Classifier
    Output["Model_variables"]=Model_variables
    Output["Time_points"]=Time_points
    return Output,Test_Data_Final,Train_Data_Final

# %%
import xgboost as xgb

clf = xgb.XGBClassifier(learning_rate=1, max_depth=5, min_child_weight=20,random_state=1)
Model_variables_con= ["Project Cost","Number of dates since posted","School Percentage Free Lunch",
                      "Project Short Description_polarity","Project Short Description_subjectivity",
                      "Project Essay_polarity","Project Essay_subjectivity","Project Need Statement_polarity",
                      "Project Need Statement_subjectivity","Teacher Project Posted Sequence"]
Model_variables_cat= ["School Metro Type","Teacher Prefix","Project Grade Level Category","Project Type",
                      "School State"]

Output,Test_Data_Final,Train_Data_Final= Train_Model(clf, Model_variables_con,Model_variables_cat,
                                    Data,Time_period_indays=30,K=100,Fund_Ratio_treshold=0.03)
# Out:
# Initiatnig the Columns
# Variables considered in model training
# > Number of dates since posted True
# > Project ID True
# > Donation Amount True
# > Project Cost True
# > Project Posted Date True
# > Project Expiration Date True
# > Donation Received Date True
# > Project Short Description_polarity True
# > Project Short Description_subjectivity True
# > Project Essay_polarity True
# > Project Essay_subjectivity True
# > Project Need Statement_polarity True
# > Project Need Statement_subjectivity True
#
# One-Hot-Encoding removing columns identification
# Initiate Time Variables
# Time iteration is starting
#
# As of Date: 2013-05-01 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8226303621885436
# 	Training_TP: 6385 	Training_FP: 1361
# 	Training_TN: 6425 	Training_FN: 1401
#
# XGBClassifier  Testing Accuracy =  0.5996596985901799
# 	Testing_TP: 1147 	Testing_FP: 882
# 	Testing_TN: 1320 	Testing_FN: 765
#
# XGBClassifier  Testing Accuracy =  0.72
# 	Testing_Top_K_TP: 72 	Testing_Top_K_FP: 28
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-05-31 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8253526858383071
# 	Training_TP: 6145 	Training_FP: 1348
# 	Training_TN: 6024 	Training_FN: 1227
#
# XGBClassifier  Testing Accuracy =  0.5797419040662284
# 	Testing_TP: 1178 	Testing_FP: 777
# 	Testing_TN: 1203 	Testing_FN: 949
#
# XGBClassifier  Testing Accuracy =  0.75
# 	Testing_Top_K_TP: 75 	Testing_Top_K_FP: 25
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-06-30 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8324920400714452
# 	Training_TP: 5381 	Training_FP: 1100
# 	Training_TN: 5339 	Training_FN: 1057
#
# XGBClassifier  Testing Accuracy =  0.6006816990036706
# 	Testing_TP: 1479 	Testing_FP: 554
# 	Testing_TN: 812 	Testing_FN: 969
#
# XGBClassifier  Testing Accuracy =  0.82
# 	Testing_Top_K_TP: 82 	Testing_Top_K_FP: 18
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-07-30 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8347652014346484
# 	Training_TP: 5050 	Training_FP: 1037
# 	Training_TN: 4958 	Training_FN: 944
#
# XGBClassifier  Testing Accuracy =  0.5756551141166526
# 	Testing_TP: 1263 	Testing_FP: 1079
# 	Testing_TN: 1461 	Testing_FN: 929
#
# XGBClassifier  Testing Accuracy =  0.66
# 	Testing_Top_K_TP: 66 	Testing_Top_K_FP: 34
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-08-29 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8334396936821953
# 	Training_TP: 5233 	Training_FP: 1053
# 	Training_TN: 5215 	Training_FN: 1035
#
# XGBClassifier  Testing Accuracy =  0.58904965129593
# 	Testing_TP: 2522 	Testing_FP: 2325
# 	Testing_TN: 3137 	Testing_FN: 1623
#
# XGBClassifier  Testing Accuracy =  0.66
# 	Testing_Top_K_TP: 66 	Testing_Top_K_FP: 34
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-09-28 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8044717471913222
# 	Training_TP: 7268 	Training_FP: 1767
# 	Training_TN: 7268 	Training_FN: 1766
#
# XGBClassifier  Testing Accuracy =  0.6079189544505452
# 	Testing_TP: 4673 	Testing_FP: 2151
# 	Testing_TN: 3188 	Testing_FN: 2919
#
# XGBClassifier  Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-10-28 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7724021567692477
# 	Training_TP: 10507 	Training_FP: 3081
# 	Training_TN: 10551 	Training_FN: 3124
#
# XGBClassifier  Testing Accuracy =  0.6071532141130981
# 	Testing_TP: 3197 	Testing_FP: 1901
# 	Testing_TN: 3084 	Testing_FN: 2163
#
# XGBClassifier  Testing Accuracy =  0.83
# 	Testing_Top_K_TP: 83 	Testing_Top_K_FP: 17
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-11-27 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7649353816142405
# 	Training_TP: 12548 	Training_FP: 3856
# 	Training_TN: 12548 	Training_FN: 3856
#
# XGBClassifier  Testing Accuracy =  0.6229318968834167
# 	Testing_TP: 3397 	Testing_FP: 1927
# 	Testing_TN: 3079 	Testing_FN: 1993
#
# XGBClassifier  Testing Accuracy =  0.93
# 	Testing_Top_K_TP: 93 	Testing_Top_K_FP: 7
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-12-27 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7634802449861895
# 	Training_TP: 12576 	Training_FP: 3800
# 	Training_TN: 12854 	Training_FN: 4078
#
# XGBClassifier  Testing Accuracy =  0.6312016865776529
# 	Testing_TP: 1577 	Testing_FP: 1654
# 	Testing_TN: 2914 	Testing_FN: 970
#
# XGBClassifier  Testing Accuracy =  0.76
# 	Testing_Top_K_TP: 76 	Testing_Top_K_FP: 24
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-01-26 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.77913886762186
# 	Training_TP: 10607 	Training_FP: 2951
# 	Training_TN: 10764 	Training_FN: 3107
#
# XGBClassifier  Testing Accuracy =  0.6044293566117038
# 	Testing_TP: 1613 	Testing_FP: 1208
# 	Testing_TN: 2126 	Testing_FN: 1239
#
# XGBClassifier  Testing Accuracy =  0.85
# 	Testing_Top_K_TP: 85 	Testing_Top_K_FP: 15
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-02-25 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7990801464951878
# 	Training_TP: 9314 	Training_FP: 2291
# 	Training_TN: 9450 	Training_FN: 2427
#
# XGBClassifier  Testing Accuracy =  0.6021435950413223
# 	Testing_TP: 1925 	Testing_FP: 1607
# 	Testing_TN: 2738 	Testing_FN: 1474
#
# XGBClassifier  Testing Accuracy =  0.82
# 	Testing_Top_K_TP: 82 	Testing_Top_K_FP: 18
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-03-27 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7833301269719123
# 	Training_TP: 8123 	Training_FP: 2232
# 	Training_TN: 8164 	Training_FN: 2273
#
# XGBClassifier  Testing Accuracy =  0.5864394746183883
# 	Testing_TP: 2513 	Testing_FP: 1712
# 	Testing_TN: 2443 	Testing_FN: 1783
#
# XGBClassifier  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-04-26 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7902694408087737
# 	Training_TP: 8767 	Training_FP: 2336
# 	Training_TN: 8743 	Training_FN: 2311
#
# XGBClassifier  Testing Accuracy =  0.5920649233543733
# 	Testing_TP: 1618 	Testing_FP: 1207
# 	Testing_TN: 1665 	Testing_FN: 1055
#
# XGBClassifier  Testing Accuracy =  0.76
# 	Testing_Top_K_TP: 76 	Testing_Top_K_FP: 24
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-05-26 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7853608439921576
# 	Training_TP: 8380 	Training_FP: 2267
# 	Training_TN: 8444 	Training_FN: 2331
#
# XGBClassifier  Testing Accuracy =  0.5923470354233756
# 	Testing_TP: 1637 	Testing_FP: 1051
# 	Testing_TN: 1490 	Testing_FN: 1101
#
# XGBClassifier  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-06-25 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7989426298157454
# 	Training_TP: 7617 	Training_FP: 1906
# 	Training_TN: 7646 	Training_FN: 1935
#
# XGBClassifier  Testing Accuracy =  0.5893552574643012
# 	Testing_TP: 1562 	Testing_FP: 862
# 	Testing_TN: 1162 	Testing_FN: 1036
#
# XGBClassifier  Testing Accuracy =  0.85
# 	Testing_Top_K_TP: 85 	Testing_Top_K_FP: 15
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-07-25 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8206873760740251
# 	Training_TP: 6233 	Training_FP: 1381
# 	Training_TN: 6184 	Training_FN: 1332
#
# XGBClassifier  Testing Accuracy =  0.5896421845574388
# 	Testing_TP: 1685 	Testing_FP: 1076
# 	Testing_TN: 1446 	Testing_FN: 1103
#
# XGBClassifier  Testing Accuracy =  0.68
# 	Testing_Top_K_TP: 68 	Testing_Top_K_FP: 32
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-08-24 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8164506744247554
# 	Training_TP: 6220 	Training_FP: 1434
# 	Training_TN: 6128 	Training_FN: 1342
#
# XGBClassifier  Testing Accuracy =  0.561531007751938
# 	Testing_TP: 3678 	Testing_FP: 3253
# 	Testing_TN: 4435 	Testing_FN: 3082
#
# XGBClassifier  Testing Accuracy =  0.68
# 	Testing_Top_K_TP: 68 	Testing_Top_K_FP: 32
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-09-23 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7683298969072165
# 	Training_TP: 9238 	Training_FP: 2731
# 	Training_TN: 9394 	Training_FN: 2887
#
# XGBClassifier  Testing Accuracy =  0.6061566782573123
# 	Testing_TP: 7250 	Testing_FP: 3254
# 	Testing_TN: 4604 	Testing_FN: 4448
#
# XGBClassifier  Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-10-23 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7484706362153344
# 	Training_TP: 14596 	Training_FP: 4848
# 	Training_TN: 14768 	Training_FN: 5020
#
# XGBClassifier  Testing Accuracy =  0.6185080264400378
# 	Testing_TP: 4096 	Testing_FP: 1880
# 	Testing_TN: 3109 	Testing_FN: 2564
#
# XGBClassifier  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-11-22 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7414135179224902
# 	Training_TP: 16676 	Training_FP: 5725
# 	Training_TN: 16956 	Training_FN: 6005
#
# XGBClassifier  Testing Accuracy =  0.618083352955027
# 	Testing_TP: 2532 	Testing_FP: 1662
# 	Testing_TN: 2718 	Testing_FN: 1582
#
# XGBClassifier  Testing Accuracy =  0.79
# 	Testing_Top_K_TP: 79 	Testing_Top_K_FP: 21
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-12-22 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7585627400768246
# 	Training_TP: 14119 	Training_FP: 4426
# 	Training_TN: 14318 	Training_FN: 4625
#
# XGBClassifier  Testing Accuracy =  0.6134747013823648
# 	Testing_TP: 1685 	Testing_FP: 1737
# 	Testing_TN: 2886 	Testing_FN: 1143
#
# XGBClassifier  Testing Accuracy =  0.68
# 	Testing_Top_K_TP: 68 	Testing_Top_K_FP: 32
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-01-21 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.769753018459393
# 	Training_TP: 10481 	Training_FP: 3131
# 	Training_TN: 10494 	Training_FN: 3143
#
# XGBClassifier  Testing Accuracy =  0.6077195746356834
# 	Testing_TP: 1842 	Testing_FP: 1669
# 	Testing_TN: 2787 	Testing_FN: 1319
#
# XGBClassifier  Testing Accuracy =  0.67
# 	Testing_Top_K_TP: 67 	Testing_Top_K_FP: 33
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-02-20 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7778065072182719
# 	Training_TP: 9065 	Training_FP: 2619
# 	Training_TN: 8984 	Training_FN: 2537
#
# XGBClassifier  Testing Accuracy =  0.6066530194472877
# 	Testing_TP: 2851 	Testing_FP: 1955
# 	Testing_TN: 3076 	Testing_FN: 1888
#
# XGBClassifier  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-03-22 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7811877565952604
# 	Training_TP: 9591 	Training_FP: 2674
# 	Training_TN: 9627 	Training_FN: 2709
#
# XGBClassifier  Testing Accuracy =  0.6579101677025918
# 	Testing_TP: 3367 	Testing_FP: 1452
# 	Testing_TN: 2243 	Testing_FN: 1465
#
# XGBClassifier  Testing Accuracy =  1.0
# 	Testing_Top_K_TP: 100 	Testing_Top_K_FP: 0
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-04-21 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7921181881967725
# 	Training_TP: 9948 	Training_FP: 2454
# 	Training_TN: 10373 	Training_FN: 2879
#
# XGBClassifier  Testing Accuracy =  0.6234263820470717
# 	Testing_TP: 2133 	Testing_FP: 1306
# 	Testing_TN: 2423 	Testing_FN: 1446
#
# XGBClassifier  Testing Accuracy =  0.9
# 	Testing_Top_K_TP: 90 	Testing_Top_K_FP: 10
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-05-21 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7998742830203505
# 	Training_TP: 9915 	Training_FP: 2282
# 	Training_TN: 10445 	Training_FN: 2812
#
# XGBClassifier  Testing Accuracy =  0.632159373888296
# 	Testing_TP: 1655 	Testing_FP: 870
# 	Testing_TN: 1899 	Testing_FN: 1198
#
# XGBClassifier  Testing Accuracy =  0.89
# 	Testing_Top_K_TP: 89 	Testing_Top_K_FP: 11
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-06-20 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8101731703864483
# 	Training_TP: 8437 	Training_FP: 1864
# 	Training_TN: 8733 	Training_FN: 2159
#
# XGBClassifier  Testing Accuracy =  0.6069771757283355
# 	Testing_TP: 1804 	Testing_FP: 825
# 	Testing_TN: 1467 	Testing_FN: 1293
#
# XGBClassifier  Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-07-20 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8122663095038786
# 	Training_TP: 7269 	Training_FP: 1674
# 	Training_TN: 7286 	Training_FN: 1690
#
# XGBClassifier  Testing Accuracy =  0.5943225286893498
# 	Testing_TP: 1430 	Testing_FP: 1034
# 	Testing_TN: 1522 	Testing_FN: 981
#
# XGBClassifier  Testing Accuracy =  0.75
# 	Testing_Top_K_TP: 75 	Testing_Top_K_FP: 25
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-08-19 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.8159408381265407
# 	Training_TP: 6452 	Training_FP: 1454
# 	Training_TN: 6457 	Training_FN: 1458
#
# XGBClassifier  Testing Accuracy =  0.5902903811252269
# 	Testing_TP: 2617 	Testing_FP: 2843
# 	Testing_TN: 3888 	Testing_FN: 1672
#
# XGBClassifier  Testing Accuracy =  0.71
# 	Testing_Top_K_TP: 71 	Testing_Top_K_FP: 29
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-09-18 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7888569949649429
# 	Training_TP: 8312 	Training_FP: 2174
# 	Training_TN: 8452 	Training_FN: 2313
#
# XGBClassifier  Testing Accuracy =  0.6042097522864103
# 	Testing_TP: 6607 	Testing_FP: 4170
# 	Testing_TN: 6540 	Testing_FN: 4442
#
# XGBClassifier  Testing Accuracy =  0.79
# 	Testing_Top_K_TP: 79 	Testing_Top_K_FP: 21
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-10-18 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7533333333333333
# 	Training_TP: 14099 	Training_FP: 4561
# 	Training_TN: 14264 	Training_FN: 4726
#
# XGBClassifier  Testing Accuracy =  0.6178810555336747
# 	Testing_TP: 3987 	Testing_FP: 2199
# 	Testing_TN: 3857 	Testing_FN: 2652
#
# XGBClassifier  Testing Accuracy =  0.83
# 	Testing_Top_K_TP: 83 	Testing_Top_K_FP: 17
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-11-17 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7431048938705265
# 	Training_TP: 16772 	Training_FP: 5754
# 	Training_TN: 16907 	Training_FN: 5889
#
# XGBClassifier  Testing Accuracy =  0.6270353598612584
# 	Testing_TP: 3247 	Testing_FP: 2000
# 	Testing_TN: 3261 	Testing_FN: 1871
#
# XGBClassifier  Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-12-17 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7480213176097064
# 	Training_TP: 16485 	Training_FP: 5549
# 	Training_TN: 16499 	Training_FN: 5562
#
# XGBClassifier  Testing Accuracy =  0.5983063328424153
# 	Testing_TP: 4045 	Testing_FP: 2933
# 	Testing_TN: 4080 	Testing_FN: 2522
#
# XGBClassifier  Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-01-16 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.750431613274506
# 	Training_TP: 13665 	Training_FP: 4527
# 	Training_TN: 13719 	Training_FN: 4580
#
# XGBClassifier  Testing Accuracy =  0.6228828206014517
# 	Testing_TP: 2506 	Testing_FP: 1735
# 	Testing_TN: 2900 	Testing_FN: 1538
#
# XGBClassifier  Testing Accuracy =  0.81
# 	Testing_Top_K_TP: 81 	Testing_Top_K_FP: 19
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-02-15 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7633540178989054
# 	Training_TP: 12197 	Training_FP: 3752
# 	Training_TN: 12283 	Training_FN: 3837
#
# XGBClassifier  Testing Accuracy =  0.6137299386606168
# 	Testing_TP: 3338 	Testing_FP: 2235
# 	Testing_TN: 3966 	Testing_FN: 2362
#
# XGBClassifier  Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-03-16 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.760873424462986
# 	Training_TP: 12872 	Training_FP: 4055
# 	Training_TN: 12844 	Training_FN: 4027
#
# XGBClassifier  Testing Accuracy =  0.6034154351395731
# 	Testing_TP: 4237 	Testing_FP: 3294
# 	Testing_TN: 4950 	Testing_FN: 2744
#
# XGBClassifier  Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-04-15 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7539025077486616
# 	Training_TP: 13242 	Training_FP: 4231
# 	Training_TN: 13514 	Training_FN: 4503
#
# XGBClassifier  Testing Accuracy =  0.5945080862533693
# 	Testing_TP: 3593 	Testing_FP: 2341
# 	Testing_TN: 3465 	Testing_FN: 2473
#
# XGBClassifier  Testing Accuracy =  0.72
# 	Testing_Top_K_TP: 72 	Testing_Top_K_FP: 28
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-05-15 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7352095156650859
# 	Training_TP: 14149 	Training_FP: 5073
# 	Training_TN: 14222 	Training_FN: 5145
#
# XGBClassifier  Testing Accuracy =  0.5950827897641746
# 	Testing_TP: 2495 	Testing_FP: 1518
# 	Testing_TN: 2249 	Testing_FN: 1710
#
# XGBClassifier  Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-06-14 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7491247866215317
# 	Training_TP: 12957 	Training_FP: 4347
# 	Training_TN: 12935 	Training_FN: 4324
#
# XGBClassifier  Testing Accuracy =  0.6028989667049368
# 	Testing_TP: 2497 	Testing_FP: 1056
# 	Testing_TN: 1704 	Testing_FN: 1711
#
# XGBClassifier  Testing Accuracy =  0.9
# 	Testing_Top_K_TP: 90 	Testing_Top_K_FP: 10
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-07-14 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7678578138503739
# 	Training_TP: 10161 	Training_FP: 3033
# 	Training_TN: 10274 	Training_FN: 3145
#
# XGBClassifier  Testing Accuracy =  0.6
# 	Testing_TP: 2417 	Testing_FP: 1466
# 	Testing_TN: 2113 	Testing_FN: 1554
#
# XGBClassifier  Testing Accuracy =  0.82
# 	Testing_Top_K_TP: 82 	Testing_Top_K_FP: 18
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-08-13 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.779999101487039
# 	Training_TP: 8727 	Training_FP: 2495
# 	Training_TN: 8635 	Training_FN: 2402
#
# XGBClassifier  Testing Accuracy =  0.6199334799030385
# 	Testing_TP: 5563 	Testing_FP: 3711
# 	Testing_TN: 5434 	Testing_FN: 3031
#
# XGBClassifier  Testing Accuracy =  0.79
# 	Testing_Top_K_TP: 79 	Testing_Top_K_FP: 21
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-09-12 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.767024530303976
# 	Training_TP: 12157 	Training_FP: 3601
# 	Training_TN: 12420 	Training_FN: 3864
#
# XGBClassifier  Testing Accuracy =  0.638606843174068
# 	Testing_TP: 8461 	Testing_FP: 4903
# 	Testing_TN: 8206 	Testing_FN: 4529
#
# XGBClassifier  Testing Accuracy =  0.9
# 	Testing_Top_K_TP: 90 	Testing_Top_K_FP: 10
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-10-12 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7478825577528705
# 	Training_TP: 19019 	Training_FP: 6347
# 	Training_TN: 19215 	Training_FN: 6542
#
# XGBClassifier  Testing Accuracy =  0.6332089307929025
# 	Testing_TP: 4864 	Testing_FP: 2615
# 	Testing_TN: 4807 	Testing_FN: 2987
#
# XGBClassifier  Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-11-11 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7478710203804116
# 	Training_TP: 21858 	Training_FP: 7276
# 	Training_TN: 22140 	Training_FN: 7557
#
# XGBClassifier  Testing Accuracy =  0.6312709030100334
# 	Testing_TP: 3101 	Testing_FP: 1869
# 	Testing_TN: 3694 	Testing_FN: 2100
#
# XGBClassifier  Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-12-11 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7472709875217247
# 	Training_TP: 19106 	Training_FP: 6444
# 	Training_TN: 19161 	Training_FN: 6498
#
# XGBClassifier  Testing Accuracy =  0.6230236156899683
# 	Testing_TP: 4159 	Testing_FP: 3245
# 	Testing_TN: 5101 	Testing_FN: 2358
#
# XGBClassifier  Testing Accuracy =  0.74
# 	Testing_Top_K_TP: 74 	Testing_Top_K_FP: 26
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-01-10 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7519788265558524
# 	Training_TP: 15223 	Training_FP: 5036
# 	Training_TN: 15178 	Training_FN: 4991
#
# XGBClassifier  Testing Accuracy =  0.6232133164465352
# 	Testing_TP: 2965 	Testing_FP: 2484
# 	Testing_TN: 3924 	Testing_FN: 1681
#
# XGBClassifier  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-02-09 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7584603532713367
# 	Training_TP: 13929 	Training_FP: 4535
# 	Training_TN: 13638 	Training_FN: 4244
#
# XGBClassifier  Testing Accuracy =  0.6302246767917661
# 	Testing_TP: 4737 	Testing_FP: 3136
# 	Testing_TN: 5305 	Testing_FN: 2756
#
# XGBClassifier  Testing Accuracy =  0.85
# 	Testing_Top_K_TP: 85 	Testing_Top_K_FP: 15
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-03-11 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7564529357842428
# 	Training_TP: 15698 	Training_FP: 5067
# 	Training_TN: 15660 	Training_FN: 5029
#
# XGBClassifier  Testing Accuracy =  0.6283430449723592
# 	Testing_TP: 3701 	Testing_FP: 2813
# 	Testing_TN: 4710 	Testing_FN: 2162
#
# XGBClassifier  Testing Accuracy =  0.81
# 	Testing_Top_K_TP: 81 	Testing_Top_K_FP: 19
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-04-10 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7563571998404468
# 	Training_TP: 15294 	Training_FP: 5011
# 	Training_TN: 15045 	Training_FN: 4762
#
# XGBClassifier  Testing Accuracy =  0.6219689119170985
# 	Testing_TP: 4328 	Testing_FP: 2549
# 	Testing_TN: 4675 	Testing_FN: 2923
#
# XGBClassifier  Testing Accuracy =  0.82
# 	Testing_Top_K_TP: 82 	Testing_Top_K_FP: 18
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-05-10 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7438445324624187
# 	Training_TP: 15853 	Training_FP: 5521
# 	Training_TN: 16261 	Training_FN: 5538
#
# XGBClassifier  Testing Accuracy =  0.6169470660648338
# 	Testing_TP: 2871 	Testing_FP: 1785
# 	Testing_TN: 3143 	Testing_FN: 1949
#
# XGBClassifier  Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-06-09 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7460991003088492
# 	Training_TP: 13517 	Training_FP: 4620
# 	Training_TN: 14264 	Training_FN: 4834
#
# XGBClassifier  Testing Accuracy =  0.6085429413097666
# 	Testing_TP: 3201 	Testing_FP: 1219
# 	Testing_TN: 2170 	Testing_FN: 2236
#
# XGBClassifier  Testing Accuracy =  0.89
# 	Testing_Top_K_TP: 89 	Testing_Top_K_FP: 11
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-07-09 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7655892713676534
# 	Training_TP: 12330 	Training_FP: 3735
# 	Training_TN: 12446 	Training_FN: 3851
#
# XGBClassifier  Testing Accuracy =  0.6051633200703248
# 	Testing_TP: 3851 	Testing_FP: 1926
# 	Testing_TN: 2689 	Testing_FN: 2341
#
# XGBClassifier  Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-08-08 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7692414031449801
# 	Training_TP: 11095 	Training_FP: 3305
# 	Training_TN: 11163 	Training_FN: 3372
#
# XGBClassifier  Testing Accuracy =  0.600705613780222
# 	Testing_TP: 5197 	Testing_FP: 4356
# 	Testing_TN: 6381 	Testing_FN: 3340
#
# XGBClassifier  Testing Accuracy =  0.82
# 	Testing_Top_K_TP: 82 	Testing_Top_K_FP: 18
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-09-07 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.746362553720292
# 	Training_TP: 14325 	Training_FP: 4809
# 	Training_TN: 14504 	Training_FN: 4988
#
# XGBClassifier  Testing Accuracy =  0.6113806960345742
# 	Testing_TP: 7826 	Testing_FP: 5387
# 	Testing_TN: 8301 	Testing_FN: 4864
#
# XGBClassifier  Testing Accuracy =  0.83
# 	Testing_Top_K_TP: 83 	Testing_Top_K_FP: 17
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-10-07 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7256722151088348
# 	Training_TP: 20258 	Training_FP: 7568
# 	Training_TN: 20548 	Training_FN: 7858
#
# XGBClassifier  Testing Accuracy =  0.6086448051644291
# 	Testing_TP: 6568 	Testing_FP: 3712
# 	Testing_TN: 6443 	Testing_FN: 4654
#
# XGBClassifier  Testing Accuracy =  0.91
# 	Testing_Top_K_TP: 91 	Testing_Top_K_FP: 9
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-11-06 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.718670881335111
# 	Training_TP: 23698 	Training_FP: 9102
# 	Training_TN: 24274 	Training_FN: 9677
#
# XGBClassifier  Testing Accuracy =  0.6168283760139971
# 	Testing_TP: 5911 	Testing_FP: 3478
# 	Testing_TN: 5723 	Testing_FN: 3749
#
# XGBClassifier  Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-12-06 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7194852661235057
# 	Training_TP: 23509 	Training_FP: 9097
# 	Training_TN: 23736 	Training_FN: 9323
#
# XGBClassifier  Testing Accuracy =  0.6220612749324597
# 	Testing_TP: 5851 	Testing_FP: 3659
# 	Testing_TN: 4971 	Testing_FN: 2916
#
# XGBClassifier  Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-01-05 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7260281167387385
# 	Training_TP: 20654 	Training_FP: 7744
# 	Training_TN: 20816 	Training_FN: 7905
#
# XGBClassifier  Testing Accuracy =  0.6186626369474877
# 	Testing_TP: 3614 	Testing_FP: 3063
# 	Testing_TN: 4574 	Testing_FN: 1984
#
# XGBClassifier  Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-02-04 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.740582436909485
# 	Training_TP: 18105 	Training_FP: 6341
# 	Training_TN: 18108 	Training_FN: 6344
#
# XGBClassifier  Testing Accuracy =  0.6109116344136162
# 	Testing_TP: 5883 	Testing_FP: 4328
# 	Testing_TN: 7218 	Testing_FN: 4016
#
# XGBClassifier  Testing Accuracy =  0.88
# 	Testing_Top_K_TP: 88 	Testing_Top_K_FP: 12
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-03-06 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7261155135334121
# 	Training_TP: 18612 	Training_FP: 6942
# 	Training_TN: 18865 	Training_FN: 7194
#
# XGBClassifier  Testing Accuracy =  0.6142751230033026
# 	Testing_TP: 3953 	Testing_FP: 2606
# 	Testing_TN: 5161 	Testing_FN: 3117
#
# XGBClassifier  Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-04-05 00:00:00
# =====================================================================================
# XGBClassifier  Testing Accuracy =  0.7325976578494799
# 	Training_TP: 17667 	Training_FP: 6479
# 	Training_TN: 18116 	Training_FN: 6582
#
# XGBClassifier  Testing Accuracy =  0.6212683347713546
# 	Testing_TP: 9489 	Testing_FP: 3353
# 	Testing_TN: 4912 	Testing_FN: 5426
#
# XGBClassifier  Testing Accuracy =  0.89
# 	Testing_Top_K_TP: 89 	Testing_Top_K_FP: 11
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0

# %%
Output.keys()
# Out:
# dict_keys(['Overall_Training_Accuracy', 'Overall_Training_Precision', 'Overall_Training_Recall', 'Overall_Testing_Accuracy', 'Overall_Testing_Precision', 'Overall_Testing_Recall', 'Top_K_Accuracy', 'Top_K_Precision', 'Top_K_Recall', 'Classifier', 'Model_variables', 'Time_points'])

# %%
X_test = Test_Data_Final.loc[:,Output["Model_variables"]]
Y_test = np.array(Test_Data_Final.loc[:,["Label"]])[:,0]

disp = plot_precision_recall_curve(Output["Classifier"], X_test, Y_test)
disp.ax_.set_title('Precision-Recall curve')
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve')

# %%
n_cols=3
n_rows=3
fig, axs=plt.subplots(n_rows,n_cols,figsize=(n_cols*6,n_rows*4))

ax = axs[0][0]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Accuracy",fontsize=15);

ax = axs[0][1]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Precision",fontsize=15);

ax = axs[0][2]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Recall",fontsize=15);

ax = axs[1][0]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Accuracy",fontsize=15);

ax = axs[1][1]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Precision",fontsize=15);

ax = axs[1][2]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Recall",fontsize=15);

ax = axs[2][0]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Accuracy",fontsize=15);

ax = axs[2][1]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Precision",fontsize=15);

ax = axs[2][2]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Recall",fontsize=15);

# %%
prT=[]
reT=[]
t=[]
k=2
Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
Test_Data_Final['Y_pred']=0
while (k<=100):
    Test_Data_Final.loc[Test_Data_Final.head(int(len(Test_Data_Final)*k/100)).index,'Y_pred'] = 1
    
    Y_test_k =  Test_Data_Final.loc[:,["Label"]] 
    Y_pred_k =  Test_Data_Final.loc[:,["Y_pred"]] 

    cm= confusion_matrix(Y_test_k,Y_pred_k)
    if len(cm.ravel())==4:TN, FP ,FN, TP =  cm.ravel()
    else: TN, FP ,FN, TP=0,0,0,100
    t+=[k]
#     print(len(Y_test_k[Y_test_k["Label"]==1])/len(Tk))
    preci=TP/(TP+FP)
    prT+=[preci]
    rec=TP/(TP+FN)
    reT+=[rec]
    k+=2
ax1=plt.plot(t,prT, 'r',label='Precision')
ax2=plt.plot(t,reT, 'b',label='Recall')
plt.xlabel("Top K as a persentage")

plt.title(Output["Classifier"].__class__.__name__+" precision and recall for different K values")
plt.legend()
plt.show()

# %%
prT=[]
reT=[]
t=[]
k=2
Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
while (k<=100):
    Tk=Test_Data_Final.head(int(len(Test_Data_Final)*k/100))
    Y_test_k =  Tk.loc[:,["Label"]] 
    Y_pred_k =  Tk.loc[:,["Y_pred"]] 
    cm= confusion_matrix(Y_test_k,Y_pred_k)
    if len(cm.ravel())==4:TN, FP ,FN, TP =  cm.ravel()
    else: TN, FP ,FN, TP=0,0,0,100
    t+=[k]
#     print(len(Y_test_k[Y_test_k["Label"]==1])/len(Tk))
    preci=TP/(TP+FP)
    prT+=[preci]
    rec=TP/(TP+FN)
    reT+=[rec]
    k+=2
ax1=plt.plot(t,prT, 'r',label='Precision')
ax2=plt.plot(t,reT, 'b',label='Recall')
plt.xlabel("Top K as a persentage")

plt.title(Output["Classifier"].__class__.__name__+" precision and recall for different K values")
plt.legend()
plt.show()

# %%
import lime
import lime.lime_tabular

X_train = Train_Data_Final.loc[:,Output["Model_variables"]]

explainer = lime.lime_tabular.LimeTabularExplainer(np.array(X_train),
                    feature_names=Output["Model_variables"], 
                    class_names=['Label'], 
                    # categorical_features=, n
                    # There is no categorical features in this example, otherwise specify them.                               
                    verbose=True, mode='regression')

explainer

# %%
exp = explainer.explain_instance(X_test.iloc[-1], Output["Classifier"].predict)
exp.as_pyplot_figure()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-24d4a2057032> in <module>
# ----> 1 exp = explainer.explain_instance(X_test.iloc[-1], Output["Classifier"].predict)
#       2 exp.as_pyplot_figure()
#
# ~\.conda\envs\Laptop\lib\site-packages\lime\lime_tabular.py in explain_instance(self, data_row, predict_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     353         ).ravel()
#     354
# --> 355         yss = predict_fn(inverse)
#     356
#     357         # for classification, the model needs to provide a list of tuples - classes
#
# ~\.conda\envs\Laptop\lib\site-packages\xgboost\sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features)
#     789                                                  output_margin=output_margin,
#     790                                                  ntree_limit=ntree_limit,
# --> 791                                                  validate_features=validate_features)
#     792         if output_margin:
#     793             # If output_margin is active, simply return the scores
#
# ~\.conda\envs\Laptop\lib\site-packages\xgboost\core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features)
#    1282
#    1283         if validate_features:
# -> 1284             self._validate_features(data)
#    1285
#    1286         length = c_bst_ulong()
#
# ~\.conda\envs\Laptop\lib\site-packages\xgboost\core.py in _validate_features(self, data)
#    1688
#    1689                 raise ValueError(msg.format(self.feature_names,
# -> 1690                                             data.feature_names))
#    1691
#    1692     def get_split_value_histogram(self, feature, fmap='', bins=None, as_pandas=True):
#
# ValueError: feature_names mismatch: ['Project Cost', 'Number of dates since posted', 'School Percentage Free Lunch', 'Project Short Description_polarity', 'Project Short Description_subjectivity', 'Project Essay_polarity', 'Project Essay_subjectivity', 'Project Need Statement_polarity', 'Project Need Statement_subjectivity', 'Teacher Project Posted Sequence', 'School Metro Type_rural', 'School Metro Type_town', 'School Metro Type_unknown', 'School Metro Type_urban', 'Teacher Prefix_Dr.', 'Teacher Prefix_Mrs.', 'Teacher Prefix_Ms.', 'Teacher Prefix_Mx.', 'Teacher Prefix_Teacher', 'Teacher Prefix_nan', 'Project Grade Level Category_Grades 3-5', 'Project Grade Level Category_Grades 9-12', 'Project Grade Level Category_Grades PreK-2', 'Project Grade Level Category_unknown', 'Project Type_Professional Development', 'Project Type_Student-Led', 'School State_Alabama', 'School State_Alaska', 'School State_Arizona', 'School State_Arkansas', 'School State_California', 'School State_Colorado', 'School State_Connecticut', 'School State_Delaware', 'School State_District of Columbia', 'School State_Florida', 'School State_Georgia', 'School State_Hawaii', 'School State_Idaho', 'School State_Illinois', 'School State_Indiana', 'School State_Iowa', 'School State_Kansas', 'School State_Kentucky', 'School State_Louisiana', 'School State_Maine', 'School State_Maryland', 'School State_Massachusetts', 'School State_Michigan', 'School State_Minnesota', 'School State_Mississippi', 'School State_Missouri', 'School State_Montana', 'School State_Nebraska', 'School State_Nevada', 'School State_New Hampshire', 'School State_New Jersey', 'School State_New Mexico', 'School State_New York', 'School State_North Carolina', 'School State_North Dakota', 'School State_Ohio', 'School State_Oklahoma', 'School State_Oregon', 'School State_Pennsylvania', 'School State_Rhode Island', 'School State_South Carolina', 'School State_South Dakota', 'School State_Tennessee', 'School State_Texas', 'School State_Vermont', 'School State_Virginia', 'School State_Washington', 'School State_West Virginia', 'School State_Wisconsin', 'School State_Wyoming'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 'f30', 'f31', 'f32', 'f33', 'f34', 'f35', 'f36', 'f37', 'f38', 'f39', 'f40', 'f41', 'f42', 'f43', 'f44', 'f45', 'f46', 'f47', 'f48', 'f49', 'f50', 'f51', 'f52', 'f53', 'f54', 'f55', 'f56', 'f57', 'f58', 'f59', 'f60', 'f61', 'f62', 'f63', 'f64', 'f65', 'f66', 'f67', 'f68', 'f69', 'f70', 'f71', 'f72', 'f73', 'f74', 'f75']
# expected School State_Washington, School State_South Dakota, School State_Minnesota, School State_New Hampshire, School Metro Type_town, Teacher Prefix_Teacher, School State_Florida, School State_Nebraska, School State_Montana, School State_Virginia, Project Essay_polarity, School State_West Virginia, School State_Iowa, School State_Oklahoma, School State_Louisiana, Project Need Statement_polarity, School State_Delaware, Project Grade Level Category_unknown, Teacher Prefix_Dr., School State_New Jersey, School State_Michigan, School State_Vermont, School State_Arizona, School State_California, Teacher Prefix_Mrs., Project Grade Level Category_Grades 9-12, School State_Hawaii, Project Cost, School State_Oregon, Project Type_Professional Development, School State_Alaska, Project Short Description_polarity, Project Grade Level Category_Grades 3-5, School State_Connecticut, School Percentage Free Lunch, School State_Idaho, Teacher Project Posted Sequence, Teacher Prefix_Ms., School State_South Carolina, School State_Colorado, School State_Indiana, School State_Rhode Island, Project Grade Level Category_Grades PreK-2, School State_Maine, School State_North Dakota, School State_Wisconsin, School State_Nevada, School State_Alabama, School State_North Carolina, School Metro Type_urban, School State_New York, Project Essay_subjectivity, School Metro Type_unknown, Project Short Description_subjectivity, School State_District of Columbia, Teacher Prefix_nan, Project Type_Student-Led, School State_Kansas, School State_Ohio, School State_Mississippi, School State_Wyoming, School State_Illinois, School State_Kentucky, School State_Georgia, Teacher Prefix_Mx., School Metro Type_rural, School State_Massachusetts, School State_Missouri, School State_New Mexico, School State_Tennessee, School State_Texas, School State_Maryland, Project Need Statement_subjectivity, School State_Pennsylvania, School State_Arkansas, Number of dates since posted in input data
# training data did not have the following fields: f51, f67, f61, f13, f22, f20, f0, f23, f57, f18, f29, f41, f3, f9, f34, f33, f4, f40, f42, f53, f54, f55, f12, f56, f60, f74, f19, f68, f44, f35, f50, f52, f58, f24, f16, f38, f47, f1, f7, f65, f39, f64, f5, f32, f66, f14, f73, f21, f70, f28, f27, f63, f37, f11, f75, f48, f26, f6, f8, f71, f45, f59, f10, f31, f30, f36, f62, f69, f43, f2, f17, f49, f15, f46, f72, f25

# %%
exp.show_in_notebook(show_table=True, show_all=False)

# %%
exp = explainer.explain_instance(X_test.iloc[0], Output["Classifier"].predict)
exp.as_pyplot_figure()

# %%
exp.show_in_notebook(show_table=True, show_all=False)

# %%
import shap
explainer = shap.TreeExplainer(Output["Classifier"])
X_train = Train_Data_Final.loc[:,Output["Model_variables"]]
shap_values = explainer.shap_values(X_train)

# %%
shap.summary_plot(shap_values, X_train)

# %%
shap.force_plot(explainer.expected_value[1], shap_values[0][0], X_test.iloc[0])
