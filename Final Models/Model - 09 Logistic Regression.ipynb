# %%
import os
import h5py
import json
import keras
import random 
import imageio
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn import tree
from keras import backend as K
from datetime import timedelta
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
# Out:
# Using TensorFlow backend.

# %%
Data = pd.read_csv('DsDnsPrScTch.csv')
# Out:
# C:\Users\REDLINE PC\.conda\envs\Laptop\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Data["Teacher First Project Posted Date"]=pd.to_datetime(Data["Teacher First Project Posted Date"])
Data["Project Fully Funded Date"]=pd.to_datetime(Data["Project Fully Funded Date"])
Data["Project Expiration Date"]=pd.to_datetime(Data["Project Expiration Date"])
Data["Project Posted Date"]=pd.to_datetime(Data["Project Posted Date"])
Data["Donation Received Date"]=pd.to_datetime(Data["Donation Received Date"])
Data["Number of dates since posted"]=Data.loc[:,"Donation Received Date"]-Data.loc[:,"Project Posted Date"]

# %%
Data.drop("Unnamed: 0", inplace=True, axis=1)
Data.drop("Unnamed: 0.1", inplace=True, axis=1)

# %%
Data.dtypes
# Out:
# Project ID                                         object
# Donation ID                                        object
# Donor ID                                           object
# Donation Included Optional Donation                object
# Donation Amount                                   float64
# Donor Cart Sequence                                 int64
# Donation Received Date                     datetime64[ns]
# Donor City                                         object
# Donor State                                        object
# Donor Is Teacher                                   object
# Donor Zip                                          object
# School ID                                          object
# Teacher ID                                         object
# Teacher Project Posted Sequence                     int64
# Project Type                                       object
# Project Title                                      object
# Project Essay                                      object
# Project Short Description                          object
# Project Need Statement                             object
# Project Subject Category Tree                      object
# Project Subject Subcategory Tree                   object
# Project Grade Level Category                       object
# Project Resource Category                          object
# Project Cost                                      float64
# Project Posted Date                        datetime64[ns]
# Project Expiration Date                    datetime64[ns]
# Project Current Status                             object
# Project Fully Funded Date                  datetime64[ns]
# Project Short Description_polarity                float64
# Project Short Description_subjectivity            float64
# Project Essay_polarity                            float64
# Project Essay_subjectivity                        float64
# Project Need Statement_polarity                   float64
# Project Need Statement_subjectivity               float64
# School Name                                        object
# School Metro Type                                  object
# School Percentage Free Lunch                      float64
# School State                                       object
# School Zip                                        float64
# School City                                        object
# School County                                      object
# School District                                    object
# Teacher Prefix                                     object
# Teacher First Project Posted Date          datetime64[ns]
# Number of dates since posted              timedelta64[ns]
# dtype: object

# %%
# from pandas import DataFrame
# import seaborn as sn
# t=Data.columns
# t=t[::-1]
# df = DataFrame(Data[t],columns=t)

# fig, ax = plt.subplots(figsize=(15,10),sharex=True, sharey=True) 
# corrMatrix = df.corr()
# sn.heatmap(corrMatrix, annot=True,annot_kws={"size": 10},ax=ax)

# %%
T=pd.Timedelta('30 days')
sub_var=["Number of dates since posted","Project ID","Donation Amount","Project Cost",
         "Project Posted Date","Project Expiration Date","Donation Received Date","Project Short Description_polarity",
        "Project Short Description_subjectivity","Project Essay_polarity","Project Essay_subjectivity",
         "Project Need Statement_polarity","Project Need Statement_subjectivity"]
sub_Data =Data.loc[:,sub_var]
sub_Data=sub_Data[sub_Data["Number of dates since posted"] < T]
sub_Data["Raised funds to project cost ratio"]=sub_Data["Donation Amount"]/sub_Data["Project Cost"]
Grouped_data=sub_Data.groupby(["Project ID"]).sum()
Grouped_data_Final = sub_Data.groupby(["Project ID"]).max()
Grouped_data_Final["Raised funds to project cost ratio"]=Grouped_data["Raised funds to project cost ratio"]

f, axes = plt.subplots(1, 1,figsize=(10,7))

y="Raised funds to project cost ratio"
q1 = Grouped_data_Final[y].quantile(0)
q3 = Grouped_data_Final[y].quantile(1)
mask = Grouped_data_Final[y].between(q1, q3, inclusive=True)
iqr = Grouped_data_Final.loc[mask, y]
sns.distplot(iqr, ax=axes,axlabel=y )
print(iqr.describe())
# Out:
# count    743945.000000
# mean          0.462287
# std           0.332363
# min           0.000030
# 25%           0.138487
# 50%           0.480108
# 75%           0.742170
# max           2.550013
# Name: Raised funds to project cost ratio, dtype: float64

# %%
Grouped_data_Final[y]
# Out:
# Project ID
# 000009891526c0ade7180f8423792063    0.207673
# 00000ce845c00cbf0686c992fc369df4    0.683031
# 00002d44003ed46b066607c5455a999a    0.399810
# 00002eb25d60a09c318efbd0797bffb5    0.107870
# 0000300773fe015f870914b42528541b    1.000000
#                                       ...
# ffff8bee61b72c484b10e43aa9e35bc9    0.524360
# ffff98098650c5e07fa7f40030fbe9e2    0.332200
# ffff9bb21699f79266cc7cbc208890a0    0.256458
# ffffd8f0fbfa10b99efe90a5ee13c5df    0.500000
# fffffcc42d1bf7ab742a4fa2d820f9f0    0.481306
# Name: Raised funds to project cost ratio, Length: 743945, dtype: float64

# %%
T=pd.Timedelta('120 days')
sub_var=["Number of dates since posted","Project ID","Donation Amount","Project Cost",
         "Project Posted Date","Project Expiration Date","Donation Received Date","Project Short Description_polarity",
        "Project Short Description_subjectivity","Project Essay_polarity","Project Essay_subjectivity",
         "Project Need Statement_polarity","Project Need Statement_subjectivity"]
sub_Data =Data.loc[:,sub_var]
sub_Data=sub_Data[sub_Data["Number of dates since posted"] < T]
sub_Data["Raised funds to project cost ratio"]=sub_Data["Donation Amount"]/sub_Data["Project Cost"]
Grouped_data=sub_Data.groupby(["Project ID"]).sum()
Grouped_data_Final = sub_Data.groupby(["Project ID"]).max()
Grouped_data_Final["Raised funds to project cost ratio"]=Grouped_data["Raised funds to project cost ratio"]

f, axes = plt.subplots(1, 1,figsize=(10,7))

y="Raised funds to project cost ratio"
q1 = Grouped_data_Final[y].quantile(0)
q3 = Grouped_data_Final[y].quantile(1)
mask = Grouped_data_Final[y].between(q1, q3, inclusive=True)
iqr = Grouped_data_Final.loc[mask, y]
sns.distplot(iqr, ax=axes,axlabel=y )
print(iqr.describe())

G120=Grouped_data_Final
# Out:
# count    870802.000000
# mean          0.555950
# std           0.337268
# min           0.000026
# 25%           0.255094
# 50%           0.500019
# 75%           0.889879
# max           2.550013
# Name: Raised funds to project cost ratio, dtype: float64

# %%
#===============================================================================================
#                                  Model Training Funstion
#===============================================================================================

def Train_Model(Classifier, Model_variables_con,Model_variables_cat,Data,
                Time_period_indays=30,K=100,Fund_Ratio_treshold=0.142):
    # Time_period should be in days 
    # K is the Top-K value

    #=================================== Initiate the List Variables ================================
    
    Time_points = []
    Output=dict()
    Output["Overall_Training_Accuracy"], Output["Overall_Training_Precision"], Output["Overall_Training_Recall"] = list(),list(),list()
    Output["Overall_Testing_Accuracy"], Output["Overall_Testing_Precision"], Output["Overall_Testing_Recall"] = list(),list(),list()
    Output["Top_K_Accuracy"], Output["Top_K_Precision"], Output["Top_K_Recall"] = list(),list(),list()

    #=================================== Initiate the Columns ======================================
    
    print("Initiatnig the Columns")
    Main_Variables = list(set(["Project ID","Project Posted Date","Project Expiration Date","Donation Received Date",
         "Project Cost","Donation Amount","Number of dates since posted"]+Model_variables_cat+Model_variables_con))
    Model_variables = Model_variables_con.copy()
    print("Variables considered in model training")
    for i in sub_var: print(">",i,i in Data.columns) # print all variables considered.
    print()
    Data["Number of dates since posted"]=Data.loc[:,"Donation Received Date"]-Data.loc[:,"Project Posted Date"]
    sub_Data = Data.loc[:,Main_Variables]
    

    #================================= One-Hot-Encoding Columns to remove ==========================
    
    print("One-Hot-Encoding removing columns identification")
    Sub_Variables_to_remove=dict()
    for i in Model_variables_cat:
        sub_variables = Data[i].unique()
        Model_variables+=sorted([i+"_"+str(j) for j in Data[i].unique()])
        Model_variables.remove(i+"_"+str(sub_variables[0]))
        Sub_Variables_to_remove[i]=sub_variables[0]
        
    
    #=================================== Initiate Time Variables ====================================
    
    print("Initiate Time Variables")
    MaxT = pd.Timestamp("2018-05-01 00:00:00")  #max(Data["Project Posted Date"])
    MinT = pd.Timestamp("2013-01-01 00:00:00")  #min(Data["Project Posted Date"])
    Time_period = timedelta(days=Time_period_indays)  
    T_current = MinT- Time_period +timedelta(days=120) 
    sub_Data["Number of dates since posted"] = sub_Data["Number of dates since posted"]/ np.timedelta64(1, 'D')
    
    
    #=================================== Loop over time frams =======================================
    
    print("Time iteration is starting\n")
    while (T_current<MaxT-Time_period):
        
        T_current = T_current+ Time_period
        Time_points+=[T_current]
        T_Train_start = T_current-timedelta(days=120)  # Start of the data frame
        T_Train_end = T_current-Time_period  #End of the data frame
        print("As of Date:",T_current,"\n"+"="*85)
        
    #====================================== Extract the frams ======================================= 
    
        # Extracts projects posted before the Current(As of) date
        Data_in_TimeWindow = sub_Data[sub_Data["Project Posted Date"] < pd.to_datetime(T_current)]  
        
        # Extracts projects posted after the start date of the Time window
        Data_in_TimeWindow = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] > pd.to_datetime(T_Train_start)]
        
        #Time period to be consided for the donations since posted (30days, as default)
        Data_in_TimeWindow = Data_in_TimeWindow[Data_in_TimeWindow["Number of dates since posted"]< Time_period_indays]
        
        #Express the donation amount as a ratio of to the Project cost
        Data_in_TimeWindow["Fund_Ratio"]=Data_in_TimeWindow["Donation Amount"]/Data_in_TimeWindow["Project Cost"]
        
        
    #=========================== Do One-Hot_Encoding for Categorical Variables ======================
    
        for var in Model_variables_cat:
            Sub_Dummied_Data=pd.get_dummies(Data_in_TimeWindow[var])  #create dummpy variables with one hot encoding 
            Sub_Dummied_Data_columns=sorted(Sub_Dummied_Data.columns)  #extract the column names of dummpy variables
            Sub_Dummied_Data_columns.remove(Sub_Variables_to_remove[var]) #remove a pre defined column from dummpy variables
            Data_in_TimeWindow=Data_in_TimeWindow.drop([var], axis=1) #remove main variable from the dataset
            #copy the columns to the main data set 
            for col in Sub_Dummied_Data_columns : Data_in_TimeWindow[var+"_"+col] = Sub_Dummied_Data[col]
                
        #Add the columns which have not been one-hot-encoded
        for i in Model_variables:
            if i not in Data_in_TimeWindow.columns:  Data_in_TimeWindow[i]=0
    
    
    #============================================ Imputing ==========================================
        Data_in_TimeWindow.fillna(Data_in_TimeWindow.median(), inplace=True)
                
    
    #=================================== Training set Creation =====================================
    
        #extract the training set from the timewindow
        Train_Data = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] < pd.to_datetime(T_Train_end)]
        
        #Group by Project ID
        Train_Data_CR=Train_Data.groupby(["Project ID"]).sum() 
        Train_Data_Final=Train_Data.groupby(["Project ID"]).max()
        Train_Data_Final["Fund_Ratio"]=Train_Data_CR["Fund_Ratio"]
        Train_Data_Final["Donation Amount"]=Train_Data_CR["Donation Amount"]
        
        # Define Fund_Ratio_Treshold
        Fund_Ratio_Treshold = Fund_Ratio_treshold
        Fund_Ratio_Treshold = Train_Data_Final["Fund_Ratio"].median()
        
        # Genarate the Label for the dataset 
        Train_Data_Final['Label'] = Train_Data_Final.apply(lambda x : 1  if x['Fund_Ratio'] < 
                                                           Fund_Ratio_Treshold  else 0, axis=1)
        
        X_train = Train_Data_Final.loc[:,Model_variables]
        Y_train = np.array(Train_Data_Final.loc[:,["Label"]])[:,0]
        
        
    #==================================== Testing set Creation =====================================
    
        #extract the training set from the timewindow
        Test_Data = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] >= pd.to_datetime(T_Train_end)]
        
        #Group by Project ID
        Test_Data_CR=Test_Data.groupby(["Project ID"]).sum() 
        Test_Data_Final=Test_Data.groupby(["Project ID"]).max()
        Test_Data_Final["Fund_Ratio"]=Test_Data_CR["Fund_Ratio"]
        Test_Data_Final["Donation Amount"]=Test_Data_CR["Donation Amount"]
        
        # Genarate the Label for the dataset 
        Test_Data_Final['Label'] = Test_Data_Final.apply(lambda x : 1  if x['Fund_Ratio'] < 
                                                         Fund_Ratio_Treshold  else 0, axis=1)
        X_test = Test_Data_Final.loc[:,Model_variables]
        Y_test = np.array(Test_Data_Final.loc[:,["Label"]])[:,0]
        
        
    #===================================== Model Training =========================================
    
        Classifier.fit(X_train, Y_train)
        
        # Predict on training 
        Train_Data_Final["Y_pred_prob"] = Classifier.predict_proba(X_train)[:,1]
        Train_Data_Final["Y_pred"]= Classifier.predict(X_train)
        # Predict on testing 
        Test_Data_Final["Y_pred_prob"] = Classifier.predict_proba(X_test)[:,1]
        Test_Data_Final["Y_pred"] = Classifier.predict(X_test)

        
    #====================================== Evaluation Trainign  ============================================
    
        Training_CM= confusion_matrix(Y_train,Train_Data_Final["Y_pred"])
        Training_TN, Training_FP ,Training_FN, Training_TP =  Training_CM.ravel()
        
        Training_Accuracy=(Training_TP+Training_TN)/(Training_TN+ Training_FP +Training_FN+ Training_TP)
        Training_Precision=Training_TP/(Training_TP+Training_FP)
        Training_Recall=Training_TP/(Training_TP+Training_FN)
        
        print(Classifier.__class__.__name__,' Trainign Accuracy = ',Training_Accuracy)
        print("\tTraining_TP:",Training_TP,"\tTraining_FP:",Training_FP,
              "\n\tTraining_TN:",Training_TN,"\tTraining_FN:",Training_FN ,end="\n"*2)
        
        
    #====================================== Evaluation Testign  ============================================   
    
        Testing_CM= confusion_matrix(Y_test,Test_Data_Final["Y_pred"])
        Testing_TN, Testing_FP ,Testing_FN, Testing_TP =  Testing_CM.ravel()
        
        Testing_Accuracy=(Testing_TP+Testing_TN)/(Testing_TN+ Testing_FP +Testing_FN+ Testing_TP)
        Testing_Precision=Testing_TP/(Testing_TP+Testing_FP)
        Testing_Recall=Testing_TP/(Testing_TP+Testing_FN)
        
        print(Classifier.__class__.__name__,' Testing Accuracy = ',Testing_Accuracy)
        print("\tTesting_TP:",Testing_TP,"\tTesting_FP:",Testing_FP,
              "\n\tTesting_TN:",Testing_TN,"\tTesting_FN:",Testing_FN ,end="\n"*2)
        
    #====================================== Evaluation Top K  ============================================        
        
        Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
        Top_K=Test_Data_Final.head(K)
        Y_test_Top_K =  Top_K.loc[:,["Label"]] 
        Y_pred_Top_K =  Top_K.loc[:,["Y_pred"]]
        Testing_Top_K_CM= confusion_matrix(Y_test_Top_K,Y_pred_Top_K)
        if len(Testing_Top_K_CM.ravel())==4:
            Testing_Top_K_TN, Testing_Top_K_FP ,Testing_Top_K_FN, Testing_Top_K_TP =  Testing_Top_K_CM.ravel()
        else:
            Testing_Top_K_TN, Testing_Top_K_FP ,Testing_Top_K_FN, Testing_Top_K_TP=0,0,0,K
        
        Testing_Top_K_Accuracy=(Testing_Top_K_TP+Testing_Top_K_TN)/(Testing_Top_K_TN
                                                                    + Testing_Top_K_FP +Testing_Top_K_FN+ Testing_Top_K_TP)
        Testing_Top_K_Precision=Testing_Top_K_TP/(Testing_Top_K_TP+Testing_Top_K_FP)
        Testing_Top_K_Recall=Testing_Top_K_TP/(Testing_Top_K_TP+Testing_Top_K_FN)
        
        print(Classifier.__class__.__name__,' Top K Testing Accuracy = ',Testing_Top_K_Accuracy)
        print("\tTesting_Top_K_TP:",Testing_Top_K_TP,"\tTesting_Top_K_FP:",Testing_Top_K_FP,
              "\n\tTesting_Top_K_TN:",Testing_Top_K_TN,"\tTesting_Top_K_FN:",Testing_Top_K_FN ,end="\n"*2)
        
     #====================================== save computed values  ============================================       
        Output["Overall_Training_Accuracy"] += [Training_Accuracy]
        Output["Overall_Training_Precision"] += [Training_Precision]
        Output["Overall_Training_Recall"] += [Training_Recall ]
        
        Output["Overall_Testing_Accuracy"] += [Testing_Accuracy]
        Output["Overall_Testing_Precision"] += [Testing_Precision]
        Output["Overall_Testing_Recall"] += [Testing_Recall]
        
        Output["Top_K_Accuracy"] += [Testing_Top_K_Accuracy] 
        Output["Top_K_Precision"] += [Testing_Top_K_Precision]  
        Output["Top_K_Recall"] += [Testing_Top_K_Recall] 
    
    
    Output["Classifier"]=Classifier
    Output["Model_variables"]=Model_variables
    Output["Time_points"]=Time_points
    return Output,Test_Data_Final,Train_Data_Final

# %%
from sklearn.linear_model import LogisticRegression 

clf = LogisticRegression(n_jobs=8, random_state=17, solver='newton-cg', tol=0.1)

Model_variables_con= ["Project Cost","Number of dates since posted","School Percentage Free Lunch",
                      "Project Short Description_polarity","Project Short Description_subjectivity",
                      "Project Essay_polarity","Project Essay_subjectivity","Project Need Statement_polarity",
                      "Project Need Statement_subjectivity","Teacher Project Posted Sequence"]
Model_variables_cat= ["School Metro Type","Teacher Prefix","Project Grade Level Category","Project Type",
                      "School State"]

Output,Test_Data_Final,Train_Data_Final= Train_Model(clf, Model_variables_con,Model_variables_cat,
                                    Data,Time_period_indays=30,K=100,Fund_Ratio_treshold=0.03)
# Out:
# Initiatnig the Columns
# Variables considered in model training
# > Number of dates since posted True
# > Project ID True
# > Donation Amount True
# > Project Cost True
# > Project Posted Date True
# > Project Expiration Date True
# > Donation Received Date True
# > Project Short Description_polarity True
# > Project Short Description_subjectivity True
# > Project Essay_polarity True
# > Project Essay_subjectivity True
# > Project Need Statement_polarity True
# > Project Need Statement_subjectivity True
#
# One-Hot-Encoding removing columns identification
# Initiate Time Variables
# Time iteration is starting
#
# As of Date: 2013-05-01 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6301053172360648
# 	Training_TP: 4620 	Training_FP: 2594
# 	Training_TN: 5192 	Training_FN: 3166
#
# LogisticRegression  Testing Accuracy =  0.6273699562469616
# 	Testing_TP: 1146 	Testing_FP: 767
# 	Testing_TN: 1435 	Testing_FN: 766
#
# LogisticRegression  Top K Testing Accuracy =  0.72
# 	Testing_Top_K_TP: 72 	Testing_Top_K_FP: 28
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-05-31 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6306972327726533
# 	Training_TP: 4448 	Training_FP: 2521
# 	Training_TN: 4851 	Training_FN: 2924
#
# LogisticRegression  Testing Accuracy =  0.6026296566837107
# 	Testing_TP: 1183 	Testing_FP: 688
# 	Testing_TN: 1292 	Testing_FN: 944
#
# LogisticRegression  Top K Testing Accuracy =  0.7
# 	Testing_Top_K_TP: 70 	Testing_Top_K_FP: 30
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-06-30 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6245243457327018
# 	Training_TP: 3906 	Training_FP: 2303
# 	Training_TN: 4136 	Training_FN: 2532
#
# LogisticRegression  Testing Accuracy =  0.534347142108023
# 	Testing_TP: 1259 	Testing_FP: 587
# 	Testing_TN: 779 	Testing_FN: 1189
#
# LogisticRegression  Top K Testing Accuracy =  0.69
# 	Testing_Top_K_TP: 69 	Testing_Top_K_FP: 31
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-07-30 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.596296605221453
# 	Training_TP: 3548 	Training_FP: 2394
# 	Training_TN: 3601 	Training_FN: 2446
#
# LogisticRegression  Testing Accuracy =  0.536770921386306
# 	Testing_TP: 1215 	Testing_FP: 1215
# 	Testing_TN: 1325 	Testing_FN: 977
#
# LogisticRegression  Top K Testing Accuracy =  0.57
# 	Testing_Top_K_TP: 57 	Testing_Top_K_FP: 43
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-08-29 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.5768187619655393
# 	Training_TP: 3551 	Training_FP: 2588
# 	Training_TN: 3680 	Training_FN: 2717
#
# LogisticRegression  Testing Accuracy =  0.5934214635161861
# 	Testing_TP: 2493 	Testing_FP: 2254
# 	Testing_TN: 3208 	Testing_FN: 1652
#
# LogisticRegression  Top K Testing Accuracy =  0.66
# 	Testing_Top_K_TP: 66 	Testing_Top_K_FP: 34
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-09-28 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.5980408434335049
# 	Training_TP: 5279 	Training_FP: 3508
# 	Training_TN: 5527 	Training_FN: 3755
#
# LogisticRegression  Testing Accuracy =  0.5497641327043539
# 	Testing_TP: 3726 	Testing_FP: 1956
# 	Testing_TN: 3383 	Testing_FN: 3866
#
# LogisticRegression  Top K Testing Accuracy =  0.77
# 	Testing_Top_K_TP: 77 	Testing_Top_K_FP: 23
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-10-28 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6022814803946741
# 	Training_TP: 8057 	Training_FP: 5269
# 	Training_TN: 8363 	Training_FN: 5574
#
# LogisticRegression  Testing Accuracy =  0.5726437892701788
# 	Testing_TP: 2873 	Testing_FP: 1934
# 	Testing_TN: 3051 	Testing_FN: 2487
#
# LogisticRegression  Top K Testing Accuracy =  0.68
# 	Testing_Top_K_TP: 68 	Testing_Top_K_FP: 32
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-11-27 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6079919531821507
# 	Training_TP: 9903 	Training_FP: 6360
# 	Training_TN: 10044 	Training_FN: 6501
#
# LogisticRegression  Testing Accuracy =  0.6124470950365525
# 	Testing_TP: 3412 	Testing_FP: 2051
# 	Testing_TN: 2955 	Testing_FN: 1978
#
# LogisticRegression  Top K Testing Accuracy =  0.51
# 	Testing_Top_K_TP: 51 	Testing_Top_K_FP: 49
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-12-27 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6425783595532605
# 	Training_TP: 10239 	Training_FP: 5490
# 	Training_TN: 11164 	Training_FN: 6415
#
# LogisticRegression  Testing Accuracy =  0.6598735066760365
# 	Testing_TP: 1465 	Testing_FP: 1338
# 	Testing_TN: 3230 	Testing_FN: 1082
#
# LogisticRegression  Top K Testing Accuracy =  0.34
# 	Testing_Top_K_TP: 34 	Testing_Top_K_FP: 66
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-01-26 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6367713004484304
# 	Training_TP: 8315 	Training_FP: 4564
# 	Training_TN: 9151 	Training_FN: 5399
#
# LogisticRegression  Testing Accuracy =  0.5916585838991271
# 	Testing_TP: 1410 	Testing_FP: 1084
# 	Testing_TN: 2250 	Testing_FN: 1442
#
# LogisticRegression  Top K Testing Accuracy =  0.68
# 	Testing_Top_K_TP: 68 	Testing_Top_K_FP: 32
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-02-25 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6441529682309854
# 	Training_TP: 7104 	Training_FP: 3719
# 	Training_TN: 8022 	Training_FN: 4637
#
# LogisticRegression  Testing Accuracy =  0.6079545454545454
# 	Testing_TP: 1830 	Testing_FP: 1467
# 	Testing_TN: 2878 	Testing_FN: 1569
#
# LogisticRegression  Top K Testing Accuracy =  0.72
# 	Testing_Top_K_TP: 72 	Testing_Top_K_FP: 28
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-03-27 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.624134282416314
# 	Training_TP: 6179 	Training_FP: 3598
# 	Training_TN: 6798 	Training_FN: 4217
#
# LogisticRegression  Testing Accuracy =  0.5925925925925926
# 	Testing_TP: 2372 	Testing_FP: 1519
# 	Testing_TN: 2636 	Testing_FN: 1924
#
# LogisticRegression  Top K Testing Accuracy =  0.65
# 	Testing_Top_K_TP: 65 	Testing_Top_K_FP: 35
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-04-26 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.624678431195559
# 	Training_TP: 6444 	Training_FP: 3682
# 	Training_TN: 7397 	Training_FN: 4634
#
# LogisticRegression  Testing Accuracy =  0.6205590622182147
# 	Testing_TP: 1566 	Testing_FP: 997
# 	Testing_TN: 1875 	Testing_FN: 1107
#
# LogisticRegression  Top K Testing Accuracy =  0.82
# 	Testing_Top_K_TP: 82 	Testing_Top_K_FP: 18
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-05-26 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6227243021193166
# 	Training_TP: 6175 	Training_FP: 3546
# 	Training_TN: 7165 	Training_FN: 4536
#
# LogisticRegression  Testing Accuracy =  0.6003030877060049
# 	Testing_TP: 1460 	Testing_FP: 832
# 	Testing_TN: 1709 	Testing_FN: 1278
#
# LogisticRegression  Top K Testing Accuracy =  0.81
# 	Testing_Top_K_TP: 81 	Testing_Top_K_FP: 19
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-06-25 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6259422110552764
# 	Training_TP: 5513 	Training_FP: 3107
# 	Training_TN: 6445 	Training_FN: 4039
#
# LogisticRegression  Testing Accuracy =  0.6077455646906101
# 	Testing_TP: 1513 	Testing_FP: 728
# 	Testing_TN: 1296 	Testing_FN: 1085
#
# LogisticRegression  Top K Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-07-25 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6245208195637806
# 	Training_TP: 4420 	Training_FP: 2536
# 	Training_TN: 5029 	Training_FN: 3145
#
# LogisticRegression  Testing Accuracy =  0.5975517890772128
# 	Testing_TP: 1684 	Testing_FP: 1033
# 	Testing_TN: 1489 	Testing_FN: 1104
#
# LogisticRegression  Top K Testing Accuracy =  0.79
# 	Testing_Top_K_TP: 79 	Testing_Top_K_FP: 21
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-08-24 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6106850039672045
# 	Training_TP: 4393 	Training_FP: 2719
# 	Training_TN: 4843 	Training_FN: 3169
#
# LogisticRegression  Testing Accuracy =  0.5701827242524917
# 	Testing_TP: 3163 	Testing_FP: 2613
# 	Testing_TN: 5075 	Testing_FN: 3597
#
# LogisticRegression  Top K Testing Accuracy =  0.85
# 	Testing_Top_K_TP: 85 	Testing_Top_K_FP: 15
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-09-23 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6137319587628866
# 	Training_TP: 6708 	Training_FP: 3950
# 	Training_TN: 8175 	Training_FN: 5417
#
# LogisticRegression  Testing Accuracy =  0.6243608099815914
# 	Testing_TP: 7013 	Testing_FP: 2661
# 	Testing_TN: 5197 	Testing_FN: 4685
#
# LogisticRegression  Top K Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-10-23 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6371329526916802
# 	Training_TP: 10368 	Training_FP: 4988
# 	Training_TN: 14628 	Training_FN: 9248
#
# LogisticRegression  Testing Accuracy =  0.6088076229719289
# 	Testing_TP: 3601 	Testing_FP: 1498
# 	Testing_TN: 3491 	Testing_FN: 3059
#
# LogisticRegression  Top K Testing Accuracy =  0.75
# 	Testing_Top_K_TP: 75 	Testing_Top_K_FP: 25
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-11-22 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6392134385609101
# 	Training_TP: 12226 	Training_FP: 5911
# 	Training_TN: 16770 	Training_FN: 10455
#
# LogisticRegression  Testing Accuracy =  0.6229102896161997
# 	Testing_TP: 2261 	Testing_FP: 1350
# 	Testing_TN: 3030 	Testing_FN: 1853
#
# LogisticRegression  Top K Testing Accuracy =  0.6
# 	Testing_Top_K_TP: 60 	Testing_Top_K_FP: 40
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-12-22 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6402848911651728
# 	Training_TP: 10550 	Training_FP: 5291
# 	Training_TN: 13453 	Training_FN: 8194
#
# LogisticRegression  Testing Accuracy =  0.6471614548382767
# 	Testing_TP: 1483 	Testing_FP: 1284
# 	Testing_TN: 3339 	Testing_FN: 1345
#
# LogisticRegression  Top K Testing Accuracy =  0.52
# 	Testing_Top_K_TP: 52 	Testing_Top_K_FP: 48
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-01-21 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6213072039340893
# 	Training_TP: 7894 	Training_FP: 4589
# 	Training_TN: 9036 	Training_FN: 5730
#
# LogisticRegression  Testing Accuracy =  0.6083760010502822
# 	Testing_TP: 1625 	Testing_FP: 1447
# 	Testing_TN: 3009 	Testing_FN: 1536
#
# LogisticRegression  Top K Testing Accuracy =  0.24
# 	Testing_Top_K_TP: 24 	Testing_Top_K_FP: 76
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-02-20 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6033613445378151
# 	Training_TP: 6650 	Training_FP: 4252
# 	Training_TN: 7351 	Training_FN: 4952
#
# LogisticRegression  Testing Accuracy =  0.5773797338792221
# 	Testing_TP: 2323 	Testing_FP: 1713
# 	Testing_TN: 3318 	Testing_FN: 2416
#
# LogisticRegression  Top K Testing Accuracy =  0.64
# 	Testing_Top_K_TP: 64 	Testing_Top_K_FP: 36
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-03-22 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6109101256046502
# 	Training_TP: 6684 	Training_FP: 3956
# 	Training_TN: 8345 	Training_FN: 5616
#
# LogisticRegression  Testing Accuracy =  0.6660021109417146
# 	Testing_TP: 3124 	Testing_FP: 1140
# 	Testing_TN: 2555 	Testing_FN: 1708
#
# LogisticRegression  Top K Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-04-21 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6453574491307399
# 	Training_TP: 6803 	Training_FP: 3074
# 	Training_TN: 9753 	Training_FN: 6024
#
# LogisticRegression  Testing Accuracy =  0.586343732895457
# 	Testing_TP: 1539 	Testing_FP: 983
# 	Testing_TN: 2746 	Testing_FN: 2040
#
# LogisticRegression  Top K Testing Accuracy =  0.79
# 	Testing_Top_K_TP: 79 	Testing_Top_K_FP: 21
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-05-21 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6665357114795317
# 	Training_TP: 7050 	Training_FP: 2811
# 	Training_TN: 9916 	Training_FN: 5677
#
# LogisticRegression  Testing Accuracy =  0.6319815012451085
# 	Testing_TP: 1368 	Testing_FP: 584
# 	Testing_TN: 2185 	Testing_FN: 1485
#
# LogisticRegression  Top K Testing Accuracy =  0.83
# 	Testing_Top_K_TP: 83 	Testing_Top_K_FP: 17
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-06-20 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.667107063653093
# 	Training_TP: 6129 	Training_FP: 2588
# 	Training_TN: 8009 	Training_FN: 4467
#
# LogisticRegression  Testing Accuracy =  0.5841529040638337
# 	Testing_TP: 1471 	Testing_FP: 615
# 	Testing_TN: 1677 	Testing_FN: 1626
#
# LogisticRegression  Top K Testing Accuracy =  0.72
# 	Testing_Top_K_TP: 72 	Testing_Top_K_FP: 28
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-07-20 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6455717394943914
# 	Training_TP: 5360 	Training_FP: 2752
# 	Training_TN: 6208 	Training_FN: 3599
#
# LogisticRegression  Testing Accuracy =  0.593718542379706
# 	Testing_TP: 1347 	Testing_FP: 954
# 	Testing_TN: 1602 	Testing_FN: 1064
#
# LogisticRegression  Top K Testing Accuracy =  0.79
# 	Testing_Top_K_TP: 79 	Testing_Top_K_FP: 21
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-08-19 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6271411415207635
# 	Training_TP: 4522 	Training_FP: 2511
# 	Training_TN: 5400 	Training_FN: 3388
#
# LogisticRegression  Testing Accuracy =  0.623956442831216
# 	Testing_TP: 2428 	Testing_FP: 2283
# 	Testing_TN: 4448 	Testing_FN: 1861
#
# LogisticRegression  Top K Testing Accuracy =  0.74
# 	Testing_Top_K_TP: 74 	Testing_Top_K_FP: 26
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-09-18 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6255235047762459
# 	Training_TP: 6004 	Training_FP: 3337
# 	Training_TN: 7289 	Training_FN: 4621
#
# LogisticRegression  Testing Accuracy =  0.6307275150512431
# 	Testing_TP: 5954 	Testing_FP: 2940
# 	Testing_TN: 7770 	Testing_FN: 5095
#
# LogisticRegression  Top K Testing Accuracy =  0.88
# 	Testing_Top_K_TP: 88 	Testing_Top_K_FP: 12
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-10-18 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6372908366533865
# 	Training_TP: 11002 	Training_FP: 5833
# 	Training_TN: 12992 	Training_FN: 7823
#
# LogisticRegression  Testing Accuracy =  0.6321386372587633
# 	Testing_TP: 3799 	Testing_FP: 1830
# 	Testing_TN: 4226 	Testing_FN: 2840
#
# LogisticRegression  Top K Testing Accuracy =  0.9
# 	Testing_Top_K_TP: 90 	Testing_Top_K_FP: 10
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-11-17 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6402630069282026
# 	Training_TP: 13338 	Training_FP: 6981
# 	Training_TN: 15680 	Training_FN: 9323
#
# LogisticRegression  Testing Accuracy =  0.6344541863377975
# 	Testing_TP: 3049 	Testing_FP: 1725
# 	Testing_TN: 3536 	Testing_FN: 2069
#
# LogisticRegression  Top K Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-12-17 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6433609252749745
# 	Training_TP: 13135 	Training_FP: 6814
# 	Training_TN: 15234 	Training_FN: 8912
#
# LogisticRegression  Testing Accuracy =  0.6201030927835052
# 	Testing_TP: 3749 	Testing_FP: 2341
# 	Testing_TN: 4672 	Testing_FN: 2818
#
# LogisticRegression  Top K Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-01-16 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6378559096763585
# 	Training_TP: 10418 	Training_FP: 5388
# 	Training_TN: 12858 	Training_FN: 7827
#
# LogisticRegression  Testing Accuracy =  0.6462726120520798
# 	Testing_TP: 2158 	Testing_FP: 1184
# 	Testing_TN: 3451 	Testing_FN: 1886
#
# LogisticRegression  Top K Testing Accuracy =  0.77
# 	Testing_Top_K_TP: 77 	Testing_Top_K_FP: 23
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-02-15 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6347251239514796
# 	Training_TP: 9157 	Training_FP: 4837
# 	Training_TN: 11198 	Training_FN: 6877
#
# LogisticRegression  Testing Accuracy =  0.6160826821275524
# 	Testing_TP: 2976 	Testing_FP: 1845
# 	Testing_TN: 4356 	Testing_FN: 2724
#
# LogisticRegression  Top K Testing Accuracy =  0.57
# 	Testing_Top_K_TP: 57 	Testing_Top_K_FP: 43
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-03-16 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6230546186164861
# 	Training_TP: 9487 	Training_FP: 5328
# 	Training_TN: 11571 	Training_FN: 7412
#
# LogisticRegression  Testing Accuracy =  0.6262725779967159
# 	Testing_TP: 3393 	Testing_FP: 2102
# 	Testing_TN: 6142 	Testing_FN: 3588
#
# LogisticRegression  Top K Testing Accuracy =  0.81
# 	Testing_Top_K_TP: 81 	Testing_Top_K_FP: 19
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-04-15 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6223161453930685
# 	Training_TP: 9867 	Training_FP: 5526
# 	Training_TN: 12219 	Training_FN: 7878
#
# LogisticRegression  Testing Accuracy =  0.6001516172506739
# 	Testing_TP: 3371 	Testing_FP: 2052
# 	Testing_TN: 3754 	Testing_FN: 2695
#
# LogisticRegression  Top K Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-05-15 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.620876415558838
# 	Training_TP: 10778 	Training_FP: 6114
# 	Training_TN: 13181 	Training_FN: 8516
#
# LogisticRegression  Testing Accuracy =  0.6107626693426994
# 	Testing_TP: 2399 	Testing_FP: 1297
# 	Testing_TN: 2470 	Testing_FN: 1806
#
# LogisticRegression  Top K Testing Accuracy =  0.79
# 	Testing_Top_K_TP: 79 	Testing_Top_K_FP: 21
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-06-14 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6288516621821022
# 	Training_TP: 9727 	Training_FP: 5274
# 	Training_TN: 12008 	Training_FN: 7554
#
# LogisticRegression  Testing Accuracy =  0.6076349024110218
# 	Testing_TP: 2372 	Testing_FP: 898
# 	Testing_TN: 1862 	Testing_FN: 1836
#
# LogisticRegression  Top K Testing Accuracy =  0.91
# 	Testing_Top_K_TP: 91 	Testing_Top_K_FP: 9
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-07-14 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6294292263179649
# 	Training_TP: 7324 	Training_FP: 3880
# 	Training_TN: 9427 	Training_FN: 5982
#
# LogisticRegression  Testing Accuracy =  0.6087417218543046
# 	Testing_TP: 2286 	Testing_FP: 1269
# 	Testing_TN: 2310 	Testing_FN: 1685
#
# LogisticRegression  Top K Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-08-13 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6182667684981356
# 	Training_TP: 5867 	Training_FP: 3235
# 	Training_TN: 7895 	Training_FN: 5262
#
# LogisticRegression  Testing Accuracy =  0.6428209030948757
# 	Testing_TP: 5038 	Testing_FP: 2780
# 	Testing_TN: 6365 	Testing_FN: 3556
#
# LogisticRegression  Top K Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-09-12 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.643124648898321
# 	Training_TP: 8865 	Training_FP: 4279
# 	Training_TN: 11742 	Training_FN: 7156
#
# LogisticRegression  Testing Accuracy =  0.6541629947507568
# 	Testing_TP: 7589 	Testing_FP: 3625
# 	Testing_TN: 9484 	Testing_FN: 5401
#
# LogisticRegression  Top K Testing Accuracy =  0.91
# 	Testing_Top_K_TP: 91 	Testing_Top_K_FP: 9
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-10-12 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6519570447743677
# 	Training_TP: 14923 	Training_FP: 7155
# 	Training_TN: 18407 	Training_FN: 10638
#
# LogisticRegression  Testing Accuracy =  0.6362862567930334
# 	Testing_TP: 4347 	Testing_FP: 2051
# 	Testing_TN: 5371 	Testing_FN: 3504
#
# LogisticRegression  Top K Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-11-11 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.654314902007445
# 	Training_TP: 17270 	Training_FP: 8192
# 	Training_TN: 21224 	Training_FN: 12145
#
# LogisticRegression  Testing Accuracy =  0.6390746934225195
# 	Testing_TP: 2912 	Testing_FP: 1596
# 	Testing_TN: 3967 	Testing_FN: 2289
#
# LogisticRegression  Top K Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-12-11 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6498467066335996
# 	Training_TP: 15058 	Training_FP: 7385
# 	Training_TN: 18220 	Training_FN: 10546
#
# LogisticRegression  Testing Accuracy =  0.6391710960102267
# 	Testing_TP: 3545 	Testing_FP: 2391
# 	Testing_TN: 5955 	Testing_FN: 2972
#
# LogisticRegression  Top K Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-01-10 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6451221925398238
# 	Training_TP: 11314 	Training_FP: 5447
# 	Training_TN: 14767 	Training_FN: 8900
#
# LogisticRegression  Testing Accuracy =  0.6523430432422652
# 	Testing_TP: 2420 	Testing_FP: 1617
# 	Testing_TN: 4791 	Testing_FN: 2226
#
# LogisticRegression  Top K Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-02-09 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6416111814229901
# 	Training_TP: 10324 	Training_FP: 5177
# 	Training_TN: 12996 	Training_FN: 7849
#
# LogisticRegression  Testing Accuracy =  0.6402660976528178
# 	Testing_TP: 4207 	Testing_FP: 2446
# 	Testing_TN: 5995 	Testing_FN: 3286
#
# LogisticRegression  Top K Testing Accuracy =  0.81
# 	Testing_Top_K_TP: 81 	Testing_Top_K_FP: 19
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-03-11 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6445940078158923
# 	Training_TP: 11841 	Training_FP: 5847
# 	Training_TN: 14880 	Training_FN: 8886
#
# LogisticRegression  Testing Accuracy =  0.6487374869266398
# 	Testing_TP: 3330 	Testing_FP: 2169
# 	Testing_TN: 5354 	Testing_FN: 2533
#
# LogisticRegression  Top K Testing Accuracy =  0.82
# 	Testing_Top_K_TP: 82 	Testing_Top_K_FP: 18
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-04-10 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6453679696848823
# 	Training_TP: 11490 	Training_FP: 5659
# 	Training_TN: 14397 	Training_FN: 8566
#
# LogisticRegression  Testing Accuracy =  0.6129188255613126
# 	Testing_TP: 3498 	Testing_FP: 1850
# 	Testing_TN: 5374 	Testing_FN: 3753
#
# LogisticRegression  Top K Testing Accuracy =  0.83
# 	Testing_Top_K_TP: 83 	Testing_Top_K_FP: 17
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-05-10 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6367173928149538
# 	Training_TP: 11633 	Training_FP: 5926
# 	Training_TN: 15856 	Training_FN: 9758
#
# LogisticRegression  Testing Accuracy =  0.6363356585966352
# 	Testing_TP: 2538 	Testing_FP: 1263
# 	Testing_TN: 3665 	Testing_FN: 2282
#
# LogisticRegression  Top K Testing Accuracy =  0.88
# 	Testing_Top_K_TP: 88 	Testing_Top_K_FP: 12
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-06-09 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6302135087954881
# 	Training_TP: 9792 	Training_FP: 5210
# 	Training_TN: 13674 	Training_FN: 8559
#
# LogisticRegression  Testing Accuracy =  0.6000453206435531
# 	Testing_TP: 2856 	Testing_FP: 949
# 	Testing_TN: 2440 	Testing_FN: 2581
#
# LogisticRegression  Top K Testing Accuracy =  0.94
# 	Testing_Top_K_TP: 94 	Testing_Top_K_FP: 6
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-07-09 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6348804153018973
# 	Training_TP: 9224 	Training_FP: 4859
# 	Training_TN: 11322 	Training_FN: 6957
#
# LogisticRegression  Testing Accuracy =  0.6019246784491533
# 	Testing_TP: 3642 	Testing_FP: 1752
# 	Testing_TN: 2863 	Testing_FN: 2550
#
# LogisticRegression  Top K Testing Accuracy =  0.92
# 	Testing_Top_K_TP: 92 	Testing_Top_K_FP: 8
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-08-08 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6390530499395196
# 	Training_TP: 8342 	Training_FP: 4319
# 	Training_TN: 10149 	Training_FN: 6125
#
# LogisticRegression  Testing Accuracy =  0.6304866659748884
# 	Testing_TP: 4828 	Testing_FP: 3413
# 	Testing_TN: 7324 	Testing_FN: 3709
#
# LogisticRegression  Top K Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-09-07 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6300937192564594
# 	Training_TP: 10700 	Training_FP: 5675
# 	Training_TN: 13638 	Training_FN: 8613
#
# LogisticRegression  Testing Accuracy =  0.6443248161346576
# 	Testing_TP: 7086 	Testing_FP: 3778
# 	Testing_TN: 9910 	Testing_FN: 5604
#
# LogisticRegression  Top K Testing Accuracy =  0.88
# 	Testing_Top_K_TP: 88 	Testing_Top_K_FP: 12
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-10-07 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6363636363636364
# 	Training_TP: 15996 	Training_FP: 8328
# 	Training_TN: 19788 	Training_FN: 12120
#
# LogisticRegression  Testing Accuracy =  0.6145857697525378
# 	Testing_TP: 6054 	Testing_FP: 3071
# 	Testing_TN: 7084 	Testing_FN: 5168
#
# LogisticRegression  Top K Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-11-06 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6341478030291681
# 	Training_TP: 18914 	Training_FP: 9960
# 	Training_TN: 23416 	Training_FN: 14461
#
# LogisticRegression  Testing Accuracy =  0.623720905572345
# 	Testing_TP: 5298 	Testing_FP: 2735
# 	Testing_TN: 6466 	Testing_FN: 4362
#
# LogisticRegression  Top K Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-12-06 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6350110408893627
# 	Training_TP: 18918 	Training_FP: 10053
# 	Training_TN: 22780 	Training_FN: 13914
#
# LogisticRegression  Testing Accuracy =  0.6249928148531356
# 	Testing_TP: 5334 	Testing_FP: 3091
# 	Testing_TN: 5539 	Testing_FN: 3433
#
# LogisticRegression  Top K Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-01-05 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6301230763843905
# 	Training_TP: 16234 	Training_FP: 8802
# 	Training_TN: 19758 	Training_FN: 12325
#
# LogisticRegression  Testing Accuracy =  0.64072534945221
# 	Testing_TP: 3297 	Testing_FP: 2454
# 	Testing_TN: 5183 	Testing_FN: 2301
#
# LogisticRegression  Top K Testing Accuracy =  0.85
# 	Testing_Top_K_TP: 85 	Testing_Top_K_FP: 15
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-02-04 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6351180007362265
# 	Training_TP: 13830 	Training_FP: 7223
# 	Training_TN: 17226 	Training_FN: 10619
#
# LogisticRegression  Testing Accuracy =  0.6351130799720215
# 	Testing_TP: 5167 	Testing_FP: 3093
# 	Testing_TN: 8453 	Testing_FN: 4732
#
# LogisticRegression  Top K Testing Accuracy =  0.89
# 	Testing_Top_K_TP: 89 	Testing_Top_K_FP: 11
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-03-06 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6247457036018057
# 	Training_TP: 14179 	Training_FP: 7741
# 	Training_TN: 18066 	Training_FN: 11627
#
# LogisticRegression  Testing Accuracy =  0.6163644941699804
# 	Testing_TP: 3586 	Testing_FP: 2208
# 	Testing_TN: 5559 	Testing_FN: 3484
#
# LogisticRegression  Top K Testing Accuracy =  0.83
# 	Testing_Top_K_TP: 83 	Testing_Top_K_FP: 17
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-04-05 00:00:00
# =====================================================================================
# LogisticRegression  Trainign Accuracy =  0.6222053885840636
# 	Training_TP: 12945 	Training_FP: 7149
# 	Training_TN: 17446 	Training_FN: 11304
#
# LogisticRegression  Testing Accuracy =  0.5950819672131148
# 	Testing_TP: 8010 	Testing_FP: 2481
# 	Testing_TN: 5784 	Testing_FN: 6905
#
# LogisticRegression  Top K Testing Accuracy =  0.95
# 	Testing_Top_K_TP: 95 	Testing_Top_K_FP: 5
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0

# %%
Output.keys()
# Out:
# dict_keys(['Overall_Training_Accuracy', 'Overall_Training_Precision', 'Overall_Training_Recall', 'Overall_Testing_Accuracy', 'Overall_Testing_Precision', 'Overall_Testing_Recall', 'Top_K_Accuracy', 'Top_K_Precision', 'Top_K_Recall', 'Classifier', 'Model_variables', 'Time_points'])

# %%
Output["Model_variables"]
# Out:
# ['Project Cost',
#  'Number of dates since posted',
#  'School Percentage Free Lunch',
#  'Project Short Description_polarity',
#  'Project Short Description_subjectivity',
#  'Project Essay_polarity',
#  'Project Essay_subjectivity',
#  'Project Need Statement_polarity',
#  'Project Need Statement_subjectivity',
#  'Teacher Project Posted Sequence',
#  'School Metro Type_rural',
#  'School Metro Type_town',
#  'School Metro Type_unknown',
#  'School Metro Type_urban',
#  'Teacher Prefix_Dr.',
#  'Teacher Prefix_Mrs.',
#  'Teacher Prefix_Ms.',
#  'Teacher Prefix_Mx.',
#  'Teacher Prefix_Teacher',
#  'Teacher Prefix_nan',
#  'Project Grade Level Category_Grades 3-5',
#  'Project Grade Level Category_Grades 9-12',
#  'Project Grade Level Category_Grades PreK-2',
#  'Project Grade Level Category_unknown',
#  'Project Type_Professional Development',
#  'Project Type_Student-Led',
#  'School State_Alabama',
#  'School State_Alaska',
#  'School State_Arizona',
#  'School State_Arkansas',
#  'School State_California',
#  'School State_Colorado',
#  'School State_Connecticut',
#  'School State_Delaware',
#  'School State_District of Columbia',
#  'School State_Florida',
#  'School State_Georgia',
#  'School State_Hawaii',
#  'School State_Idaho',
#  'School State_Illinois',
#  'School State_Indiana',
#  'School State_Iowa',
#  'School State_Kansas',
#  'School State_Kentucky',
#  'School State_Louisiana',
#  'School State_Maine',
#  'School State_Maryland',
#  'School State_Massachusetts',
#  'School State_Michigan',
#  'School State_Minnesota',
#  'School State_Mississippi',
#  'School State_Missouri',
#  'School State_Montana',
#  'School State_Nebraska',
#  'School State_Nevada',
#  'School State_New Hampshire',
#  'School State_New Jersey',
#  'School State_New Mexico',
#  'School State_New York',
#  'School State_North Carolina',
#  'School State_North Dakota',
#  'School State_Ohio',
#  'School State_Oklahoma',
#  'School State_Oregon',
#  'School State_Pennsylvania',
#  'School State_Rhode Island',
#  'School State_South Carolina',
#  'School State_South Dakota',
#  'School State_Tennessee',
#  'School State_Texas',
#  'School State_Vermont',
#  'School State_Virginia',
#  'School State_Washington',
#  'School State_West Virginia',
#  'School State_Wisconsin',
#  'School State_Wyoming']

# %%
X_test = Test_Data_Final.loc[:,Output["Model_variables"]]
Y_test = np.array(Test_Data_Final.loc[:,["Label"]])[:,0]

disp = plot_precision_recall_curve(Output["Classifier"], X_test, Y_test)
disp.ax_.set_title('Precision-Recall curve')
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve')

# %%
n_cols=3
n_rows=3
fig, axs=plt.subplots(n_rows,n_cols,figsize=(n_cols*6,n_rows*4))

ax = axs[0][0]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Accuracy",fontsize=15);

ax = axs[0][1]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Precision",fontsize=15);

ax = axs[0][2]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Recall",fontsize=15);

ax = axs[1][0]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Accuracy",fontsize=15);

ax = axs[1][1]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Precision",fontsize=15);

ax = axs[1][2]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Recall",fontsize=15);

ax = axs[2][0]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Accuracy",fontsize=15);

ax = axs[2][1]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Precision",fontsize=15);

ax = axs[2][2]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Recall",fontsize=15);

# %%
prT=[]
reT=[]
t=[]
k=2
Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
Test_Data_Final['Y_pred']=0
while (k<=100):
    Test_Data_Final.loc[Test_Data_Final.head(int(len(Test_Data_Final)*k/100)).index,'Y_pred'] = 1
    
    Y_test_k =  Test_Data_Final.loc[:,["Label"]] 
    Y_pred_k =  Test_Data_Final.loc[:,["Y_pred"]] 

    cm= confusion_matrix(Y_test_k,Y_pred_k)
    if len(cm.ravel())==4:TN, FP ,FN, TP =  cm.ravel()
    else: TN, FP ,FN, TP=0,0,0,100
    t+=[k]
#     print(len(Y_test_k[Y_test_k["Label"]==1])/len(Tk))
    preci=TP/(TP+FP)
    prT+=[preci]
    rec=TP/(TP+FN)
    reT+=[rec]
    k+=2
ax1=plt.plot(t,prT, 'r',label='Precision')
ax2=plt.plot(t,reT, 'b',label='Recall')
plt.xlabel("Top K as a persentage")

plt.title(Output["Classifier"].__class__.__name__+" precision and recall for different K values")
plt.legend()
plt.show()

# %%
prT=[]
reT=[]
t=[]
k=2
Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
while (k<=100):
    Tk=Test_Data_Final.head(int(len(Test_Data_Final)*k/100))
    Y_test_k =  Tk.loc[:,["Label"]] 
    Y_pred_k =  Tk.loc[:,["Y_pred"]] 
    cm= confusion_matrix(Y_test_k,Y_pred_k)
    if len(cm.ravel())==4:TN, FP ,FN, TP =  cm.ravel()
    else: TN, FP ,FN, TP=0,0,0,100
    t+=[k]
#     print(len(Y_test_k[Y_test_k["Label"]==1])/len(Tk))
    preci=TP/(TP+FP)
    prT+=[preci]
    rec=TP/(TP+FN)
    reT+=[rec]
    k+=2
ax1=plt.plot(t,prT, 'r',label='Precision')
ax2=plt.plot(t,reT, 'b',label='Recall')
plt.xlabel("Top K as a persentage")

plt.title(Output["Classifier"].__class__.__name__+" precision and recall for different K values")
plt.legend()
plt.show()

# %%
import lime
import lime.lime_tabular

X_train = Train_Data_Final.loc[:,Output["Model_variables"]]

explainer = lime.lime_tabular.LimeTabularExplainer(np.array(X_train),
                    feature_names=Output["Model_variables"], 
                    class_names=['Label'], 
                    # categorical_features=, n
                    # There is no categorical features in this example, otherwise specify them.                               
                    verbose=True, mode='regression')

explainer

# %%
exp = explainer.explain_instance(X_test.iloc[-1], Output["Classifier"].predict)
exp.as_pyplot_figure()
# Out:
# Intercept 0.6098078079935647
# Prediction_local [-0.17431025]
# Right: 0

# %%
exp.show_in_notebook(show_table=True, show_all=False)
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %%
exp = explainer.explain_instance(X_test.iloc[0], Output["Classifier"].predict)
exp.as_pyplot_figure()
# Out:
# Intercept 0.22096994396842662
# Prediction_local [1.17467282]
# Right: 1

# %%
exp.show_in_notebook(show_table=True, show_all=False)
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %%
import shap
explainer = shap.TreeExplainer(Output["Classifier"])
X_train = Train_Data_Final.loc[:,Output["Model_variables"]]
shap_values = explainer.shap_values(X_train)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-23-1ce550c5bd9a> in <module>
#       1 import shap
# ----> 2 explainer = shap.TreeExplainer(Output["Classifier"])
#       3 X_train = Train_Data_Final.loc[:,Output["Model_variables"]]
#       4 shap_values = explainer.shap_values(X_train)
#
# ~\.conda\envs\Laptop\lib\site-packages\shap\explainers\_tree.py in __init__(self, model, data, model_output, feature_perturbation, **deprecated_options)
#     134         self.feature_perturbation = feature_perturbation
#     135         self.expected_value = None
# --> 136         self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     137         self.model_output = model_output
#     138         #self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#
# ~\.conda\envs\Laptop\lib\site-packages\shap\explainers\_tree.py in __init__(self, model, data, data_missing, model_output)
#     943             self.base_offset = model.init_params[param_idx]
#     944         else:
# --> 945             raise Exception("Model type not yet supported by TreeExplainer: " + str(type(model)))
#     946
#     947         # build a dense numpy version of all the tree objects
#
# Exception: Model type not yet supported by TreeExplainer: <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
shap.summary_plot(shap_values, X_train)

# %%
shap.force_plot(explainer.expected_value[1], shap_values[0][0], X_test.iloc[0])
