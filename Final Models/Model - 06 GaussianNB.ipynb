# %%
import os
import h5py
import json
import keras
import random 
import imageio
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn import tree
from keras import backend as K
from datetime import timedelta
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
# Out:
# Using TensorFlow backend.

# %%
Data = pd.read_csv('DsDnsPrScTch.csv')
# Out:
# C:\Users\REDLINE PC\.conda\envs\Laptop\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Data["Teacher First Project Posted Date"]=pd.to_datetime(Data["Teacher First Project Posted Date"])
Data["Project Fully Funded Date"]=pd.to_datetime(Data["Project Fully Funded Date"])
Data["Project Expiration Date"]=pd.to_datetime(Data["Project Expiration Date"])
Data["Project Posted Date"]=pd.to_datetime(Data["Project Posted Date"])
Data["Donation Received Date"]=pd.to_datetime(Data["Donation Received Date"])
Data["Number of dates since posted"]=Data.loc[:,"Donation Received Date"]-Data.loc[:,"Project Posted Date"]

# %%
Data.dtypes
# Out:
# Unnamed: 0                                          int64
# Project ID                                         object
# Donation ID                                        object
# Donor ID                                           object
# Donation Included Optional Donation                object
# Donation Amount                                   float64
# Donor Cart Sequence                                 int64
# Donation Received Date                     datetime64[ns]
# Donor City                                         object
# Donor State                                        object
# Donor Is Teacher                                   object
# Donor Zip                                          object
# Unnamed: 0.1                                        int64
# School ID                                          object
# Teacher ID                                         object
# Teacher Project Posted Sequence                     int64
# Project Type                                       object
# Project Title                                      object
# Project Essay                                      object
# Project Short Description                          object
# Project Need Statement                             object
# Project Subject Category Tree                      object
# Project Subject Subcategory Tree                   object
# Project Grade Level Category                       object
# Project Resource Category                          object
# Project Cost                                      float64
# Project Posted Date                        datetime64[ns]
# Project Expiration Date                    datetime64[ns]
# Project Current Status                             object
# Project Fully Funded Date                  datetime64[ns]
# Project Short Description_polarity                float64
# Project Short Description_subjectivity            float64
# Project Essay_polarity                            float64
# Project Essay_subjectivity                        float64
# Project Need Statement_polarity                   float64
# Project Need Statement_subjectivity               float64
# School Name                                        object
# School Metro Type                                  object
# School Percentage Free Lunch                      float64
# School State                                       object
# School Zip                                        float64
# School City                                        object
# School County                                      object
# School District                                    object
# Teacher Prefix                                     object
# Teacher First Project Posted Date          datetime64[ns]
# Number of dates since posted              timedelta64[ns]
# dtype: object

# %%
T=pd.Timedelta('30 days')
sub_var=["Number of dates since posted","Project ID","Donation Amount","Project Cost",
         "Project Posted Date","Project Expiration Date","Donation Received Date","Project Short Description_polarity",
        "Project Short Description_subjectivity","Project Essay_polarity","Project Essay_subjectivity",
         "Project Need Statement_polarity","Project Need Statement_subjectivity"]
sub_Data =Data.loc[:,sub_var]
sub_Data=sub_Data[sub_Data["Number of dates since posted"] < T]
sub_Data["Raised funds to project cost ratio"]=sub_Data["Donation Amount"]/sub_Data["Project Cost"]
Grouped_data=sub_Data.groupby(["Project ID"]).sum()
Grouped_data_Final = sub_Data.groupby(["Project ID"]).max()
Grouped_data_Final["Raised funds to project cost ratio"]=Grouped_data["Raised funds to project cost ratio"]

f, axes = plt.subplots(1, 1,figsize=(10,7))

y="Raised funds to project cost ratio"
q1 = Grouped_data_Final[y].quantile(0)
q3 = Grouped_data_Final[y].quantile(1)
mask = Grouped_data_Final[y].between(q1, q3, inclusive=True)
iqr = Grouped_data_Final.loc[mask, y]
sns.distplot(iqr, ax=axes,axlabel=y )
print(iqr.describe())
# Out:
# count    743945.000000
# mean          0.462287
# std           0.332363
# min           0.000030
# 25%           0.138487
# 50%           0.480108
# 75%           0.742170
# max           2.550013
# Name: Raised funds to project cost ratio, dtype: float64

# %%
T=pd.Timedelta('120 days')
sub_var=["Number of dates since posted","Project ID","Donation Amount","Project Cost",
         "Project Posted Date","Project Expiration Date","Donation Received Date","Project Short Description_polarity",
        "Project Short Description_subjectivity","Project Essay_polarity","Project Essay_subjectivity",
         "Project Need Statement_polarity","Project Need Statement_subjectivity"]
sub_Data =Data.loc[:,sub_var]
sub_Data=sub_Data[sub_Data["Number of dates since posted"] < T]
sub_Data["Raised funds to project cost ratio"]=sub_Data["Donation Amount"]/sub_Data["Project Cost"]
Grouped_data=sub_Data.groupby(["Project ID"]).sum()
Grouped_data_Final = sub_Data.groupby(["Project ID"]).max()
Grouped_data_Final["Raised funds to project cost ratio"]=Grouped_data["Raised funds to project cost ratio"]

f, axes = plt.subplots(1, 1,figsize=(10,7))

y="Raised funds to project cost ratio"
q1 = Grouped_data_Final[y].quantile(0)
q3 = Grouped_data_Final[y].quantile(1)
mask = Grouped_data_Final[y].between(q1, q3, inclusive=True)
iqr = Grouped_data_Final.loc[mask, y]
sns.distplot(iqr, ax=axes,axlabel=y )
print(iqr.describe())

G120=Grouped_data_Final
# Out:
# count    870802.000000
# mean          0.555950
# std           0.337268
# min           0.000026
# 25%           0.255094
# 50%           0.500019
# 75%           0.889879
# max           2.550013
# Name: Raised funds to project cost ratio, dtype: float64

# %%
#===============================================================================================
#                                  Model Training Funstion
#===============================================================================================

def Train_Model(Classifier, Model_variables_con,Model_variables_cat,Data,
                Time_period_indays=30,K=100,Fund_Ratio_treshold=0.142):
    # Time_period should be in days 
    # K is the Top-K value

    #=================================== Initiate the List Variables ================================
    
    Time_points = []
    Output=dict()
    Output["Overall_Training_Accuracy"], Output["Overall_Training_Precision"], Output["Overall_Training_Recall"] = list(),list(),list()
    Output["Overall_Testing_Accuracy"], Output["Overall_Testing_Precision"], Output["Overall_Testing_Recall"] = list(),list(),list()
    Output["Top_K_Accuracy"], Output["Top_K_Precision"], Output["Top_K_Recall"] = list(),list(),list()

    #=================================== Initiate the Columns ======================================
    
    print("Initiatnig the Columns")
    Main_Variables = list(set(["Project ID","Project Posted Date","Project Expiration Date","Donation Received Date",
         "Project Cost","Donation Amount","Number of dates since posted"]+Model_variables_cat+Model_variables_con))
    Model_variables = Model_variables_con.copy()
    print("Variables considered in model training")
    for i in sub_var: print(">",i,i in Data.columns) # print all variables considered.
    print()
    Data["Number of dates since posted"]=Data.loc[:,"Donation Received Date"]-Data.loc[:,"Project Posted Date"]
    sub_Data = Data.loc[:,Main_Variables]
    

    #================================= One-Hot-Encoding Columns to remove ==========================
    
    print("One-Hot-Encoding removing columns identification")
    Sub_Variables_to_remove=dict()
    for i in Model_variables_cat:
        sub_variables = Data[i].unique()
        Model_variables+=sorted([i+"_"+str(j) for j in Data[i].unique()])
        Model_variables.remove(i+"_"+str(sub_variables[0]))
        Sub_Variables_to_remove[i]=sub_variables[0]
        
    
    #=================================== Initiate Time Variables ====================================
    
    print("Initiate Time Variables")
    MaxT = pd.Timestamp("2018-05-01 00:00:00")  #max(Data["Project Posted Date"])
    MinT = pd.Timestamp("2013-01-01 00:00:00")  #min(Data["Project Posted Date"])
    Time_period = timedelta(days=Time_period_indays)  
    T_current = MinT- Time_period +timedelta(days=120) 
    sub_Data["Number of dates since posted"] = sub_Data["Number of dates since posted"]/ np.timedelta64(1, 'D')
    
    
    #=================================== Loop over time frams =======================================
    
    print("Time iteration is starting\n")
    while (T_current<MaxT-Time_period):
        
        T_current = T_current+ Time_period
        Time_points+=[T_current]
        T_Train_start = T_current-timedelta(days=120)  # Start of the data frame
        T_Train_end = T_current-Time_period  #End of the data frame
        print("As of Date:",T_current,"\n"+"="*85)
        
    #====================================== Extract the frams ======================================= 
    
        # Extracts projects posted before the Current(As of) date
        Data_in_TimeWindow = sub_Data[sub_Data["Project Posted Date"] < pd.to_datetime(T_current)]  
        
        # Extracts projects posted after the start date of the Time window
        Data_in_TimeWindow = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] > pd.to_datetime(T_Train_start)]
        
        #Time period to be consided for the donations since posted (30days, as default)
        Data_in_TimeWindow = Data_in_TimeWindow[Data_in_TimeWindow["Number of dates since posted"]< Time_period_indays]
        
        #Express the donation amount as a ratio of to the Project cost
        Data_in_TimeWindow["Fund_Ratio"]=Data_in_TimeWindow["Donation Amount"]/Data_in_TimeWindow["Project Cost"]
        
        
    #=========================== Do One-Hot_Encoding for Categorical Variables ======================
    
        for var in Model_variables_cat:
            Sub_Dummied_Data=pd.get_dummies(Data_in_TimeWindow[var])  #create dummpy variables with one hot encoding 
            Sub_Dummied_Data_columns=sorted(Sub_Dummied_Data.columns)  #extract the column names of dummpy variables
            Sub_Dummied_Data_columns.remove(Sub_Variables_to_remove[var]) #remove a pre defined column from dummpy variables
            Data_in_TimeWindow=Data_in_TimeWindow.drop([var], axis=1) #remove main variable from the dataset
            #copy the columns to the main data set 
            for col in Sub_Dummied_Data_columns : Data_in_TimeWindow[var+"_"+col] = Sub_Dummied_Data[col]
                
        #Add the columns which have not been one-hot-encoded
        for i in Model_variables:
            if i not in Data_in_TimeWindow.columns:  Data_in_TimeWindow[i]=0
    
    
    #============================================ Imputing ==========================================
        Data_in_TimeWindow.fillna(Data_in_TimeWindow.median(), inplace=True)
                
    
    #=================================== Training set Creation =====================================
    
        #extract the training set from the timewindow
        Train_Data = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] < pd.to_datetime(T_Train_end)]
        
        #Group by Project ID
        Train_Data_CR=Train_Data.groupby(["Project ID"]).sum() 
        Train_Data_Final=Train_Data.groupby(["Project ID"]).max()
        Train_Data_Final["Fund_Ratio"]=Train_Data_CR["Fund_Ratio"]
        Train_Data_Final["Donation Amount"]=Train_Data_CR["Donation Amount"]
        
        # Define Fund_Ratio_Treshold
        Fund_Ratio_Treshold = Fund_Ratio_treshold
        Fund_Ratio_Treshold = Train_Data_Final["Fund_Ratio"].median()
        
        # Genarate the Label for the dataset 
        Train_Data_Final['Label'] = Train_Data_Final.apply(lambda x : 1  if x['Fund_Ratio'] < 
                                                           Fund_Ratio_Treshold  else 0, axis=1)
        
        X_train = Train_Data_Final.loc[:,Model_variables]
        Y_train = np.array(Train_Data_Final.loc[:,["Label"]])[:,0]
        
        
    #==================================== Testing set Creation =====================================
    
        #extract the training set from the timewindow
        Test_Data = Data_in_TimeWindow[Data_in_TimeWindow["Project Posted Date"] >= pd.to_datetime(T_Train_end)]
        
        #Group by Project ID
        Test_Data_CR=Test_Data.groupby(["Project ID"]).sum() 
        Test_Data_Final=Test_Data.groupby(["Project ID"]).max()
        Test_Data_Final["Fund_Ratio"]=Test_Data_CR["Fund_Ratio"]
        Test_Data_Final["Donation Amount"]=Test_Data_CR["Donation Amount"]
        
        # Genarate the Label for the dataset 
        Test_Data_Final['Label'] = Test_Data_Final.apply(lambda x : 1  if x['Fund_Ratio'] < 
                                                         Fund_Ratio_Treshold  else 0, axis=1)
        X_test = Test_Data_Final.loc[:,Model_variables]
        Y_test = np.array(Test_Data_Final.loc[:,["Label"]])[:,0]
        
        
    #===================================== Model Training =========================================
    
        Classifier.fit(X_train, Y_train)
        
        # Predict on training 
        Train_Data_Final["Y_pred_prob"] = Classifier.predict_proba(X_train)[:,1]
        Train_Data_Final["Y_pred"]= Classifier.predict(X_train)
        # Predict on testing 
        Test_Data_Final["Y_pred_prob"] = Classifier.predict_proba(X_test)[:,1]
        Test_Data_Final["Y_pred"] = Classifier.predict(X_test)

        
    #====================================== Evaluation Trainign  ============================================
    
        Training_CM= confusion_matrix(Y_train,Train_Data_Final["Y_pred"])
        Training_TN, Training_FP ,Training_FN, Training_TP =  Training_CM.ravel()
        
        Training_Accuracy=(Training_TP+Training_TN)/(Training_TN+ Training_FP +Training_FN+ Training_TP)
        Training_Precision=Training_TP/(Training_TP+Training_FP)
        Training_Recall=Training_TP/(Training_TP+Training_FN)
        
        print(Classifier.__class__.__name__,' Testing Accuracy = ',Training_Accuracy)
        print("\tTraining_TP:",Training_TP,"\tTraining_FP:",Training_FP,
              "\n\tTraining_TN:",Training_TN,"\tTraining_FN:",Training_FN ,end="\n"*2)
        
        
    #====================================== Evaluation Testign  ============================================   
    
        Testing_CM= confusion_matrix(Y_test,Test_Data_Final["Y_pred"])
        Testing_TN, Testing_FP ,Testing_FN, Testing_TP =  Testing_CM.ravel()
        
        Testing_Accuracy=(Testing_TP+Testing_TN)/(Testing_TN+ Testing_FP +Testing_FN+ Testing_TP)
        Testing_Precision=Testing_TP/(Testing_TP+Testing_FP)
        Testing_Recall=Testing_TP/(Testing_TP+Testing_FN)
        
        print(Classifier.__class__.__name__,' Testing Accuracy = ',Testing_Accuracy)
        print("\tTesting_TP:",Testing_TP,"\tTesting_FP:",Testing_FP,
              "\n\tTesting_TN:",Testing_TN,"\tTesting_FN:",Testing_FN ,end="\n"*2)
        
    #====================================== Evaluation Top K  ============================================        
        
        Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
        Top_K=Test_Data_Final.head(K)
        Y_test_Top_K =  Top_K.loc[:,["Label"]] 
        Y_pred_Top_K =  Top_K.loc[:,["Y_pred"]]
        Testing_Top_K_CM= confusion_matrix(Y_test_Top_K,Y_pred_Top_K)
        if len(Testing_Top_K_CM.ravel())==4:
            Testing_Top_K_TN, Testing_Top_K_FP ,Testing_Top_K_FN, Testing_Top_K_TP =  Testing_Top_K_CM.ravel()
        else:
            Testing_Top_K_TN, Testing_Top_K_FP ,Testing_Top_K_FN, Testing_Top_K_TP=0,0,0,K
        
        Testing_Top_K_Accuracy=(Testing_Top_K_TP+Testing_Top_K_TN)/(Testing_Top_K_TN
                                                                        + Testing_Top_K_FP +Testing_Top_K_FN+ Testing_Top_K_TP)
        Testing_Top_K_Precision=Testing_Top_K_TP/(Testing_TP+Testing_FP)
        Testing_Top_K_Recall=Testing_Top_K_TP/(Testing_TP+Testing_FN)
        
        print(Classifier.__class__.__name__,' Testing Accuracy = ',Testing_Top_K_Accuracy)
        print("\tTesting_Top_K_TP:",Testing_Top_K_TP,"\tTesting_Top_K_FP:",Testing_Top_K_FP,
              "\n\tTesting_Top_K_TN:",Testing_Top_K_TN,"\tTesting_Top_K_FN:",Testing_Top_K_FN ,end="\n"*2)
        
     #====================================== save computed values  ============================================       
        Output["Overall_Training_Accuracy"] += [Training_Accuracy]
        Output["Overall_Training_Precision"] += [Training_Precision]
        Output["Overall_Training_Recall"] += [Training_Recall ]
        
        Output["Overall_Testing_Accuracy"] += [Testing_Accuracy]
        Output["Overall_Testing_Precision"] += [Testing_Precision]
        Output["Overall_Testing_Recall"] += [Testing_Recall]
        
        Output["Top_K_Accuracy"] += [Testing_Top_K_Accuracy] 
        Output["Top_K_Precision"] += [Testing_Top_K_Precision]  
        Output["Top_K_Recall"] += [Testing_Top_K_Recall] 
    
    
    Output["Classifier"]=Classifier
    Output["Model_variables"]=Model_variables
    Output["Time_points"]=Time_points
    return Output,Test_Data_Final,Train_Data_Final

# %%
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()

Model_variables_con= ["Project Cost","Number of dates since posted","School Percentage Free Lunch","Project Cost",
                      "Project Short Description_polarity","Project Short Description_subjectivity",
                      "Project Essay_polarity","Project Essay_subjectivity","Project Need Statement_polarity",
                      "Project Need Statement_subjectivity"]
Model_variables_cat= ["School Metro Type","Teacher Prefix","Project Grade Level Category"]
Output,Test_Data_Final,Train_Data_Final= Train_Model(clf, Model_variables_con,Model_variables_cat,
                                    Data,Time_period_indays=30,K=100,Fund_Ratio_treshold=0.03)
# Out:
# Initiatnig the Columns
# Variables considered in model training
# > Number of dates since posted True
# > Project ID True
# > Donation Amount True
# > Project Cost True
# > Project Posted Date True
# > Project Expiration Date True
# > Donation Received Date True
# > Project Short Description_polarity True
# > Project Short Description_subjectivity True
# > Project Essay_polarity True
# > Project Essay_subjectivity True
# > Project Need Statement_polarity True
# > Project Need Statement_subjectivity True
#
# One-Hot-Encoding removing columns identification
# Initiate Time Variables
# Time iteration is starting
#
# As of Date: 2013-05-01 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5451451322887233
# 	Training_TP: 1470 	Training_FP: 767
# 	Training_TN: 7019 	Training_FN: 6316
#
# GaussianNB  Testing Accuracy =  0.5692756441419543
# 	Testing_TP: 364 	Testing_FP: 224
# 	Testing_TN: 1978 	Testing_FN: 1548
#
# GaussianNB  Testing Accuracy =  0.7
# 	Testing_Top_K_TP: 70 	Testing_Top_K_FP: 30
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-05-31 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.4950488334237656
# 	Training_TP: 7173 	Training_FP: 7246
# 	Training_TN: 126 	Training_FN: 199
#
# GaussianNB  Testing Accuracy =  0.5125395665936207
# 	Testing_TP: 2072 	Testing_FP: 1947
# 	Testing_TN: 33 	Testing_FN: 55
#
# GaussianNB  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-06-30 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.49794206725168905
# 	Training_TP: 6239 	Training_FP: 6266
# 	Training_TN: 173 	Training_FN: 199
#
# GaussianNB  Testing Accuracy =  0.6355532249606712
# 	Testing_TP: 2382 	Testing_FP: 1324
# 	Testing_TN: 42 	Testing_FN: 66
#
# GaussianNB  Testing Accuracy =  0.69
# 	Testing_Top_K_TP: 69 	Testing_Top_K_FP: 31
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-07-30 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.49637167403453164
# 	Training_TP: 5850 	Training_FP: 5894
# 	Training_TN: 101 	Training_FN: 144
#
# GaussianNB  Testing Accuracy =  0.46682163989856296
# 	Testing_TP: 2136 	Testing_FP: 2467
# 	Testing_TN: 73 	Testing_FN: 56
#
# GaussianNB  Testing Accuracy =  0.59
# 	Testing_Top_K_TP: 59 	Testing_Top_K_FP: 41
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-08-29 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5512125079770261
# 	Training_TP: 3890 	Training_FP: 3248
# 	Training_TN: 3020 	Training_FN: 2378
#
# GaussianNB  Testing Accuracy =  0.566774227126054
# 	Testing_TP: 2707 	Testing_FP: 2724
# 	Testing_TN: 2738 	Testing_FN: 1438
#
# GaussianNB  Testing Accuracy =  0.58
# 	Testing_Top_K_TP: 58 	Testing_Top_K_FP: 42
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-09-28 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5452432342686369
# 	Training_TP: 7632 	Training_FP: 6815
# 	Training_TN: 2220 	Training_FN: 1402
#
# GaussianNB  Testing Accuracy =  0.5558734823292862
# 	Testing_TP: 5953 	Testing_FP: 4104
# 	Testing_TN: 1235 	Testing_FN: 1639
#
# GaussianNB  Testing Accuracy =  0.69
# 	Testing_Top_K_TP: 69 	Testing_Top_K_FP: 31
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-10-28 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.55081979239262
# 	Training_TP: 10329 	Training_FP: 8944
# 	Training_TN: 4688 	Training_FN: 3302
#
# GaussianNB  Testing Accuracy =  0.5354277428709522
# 	Testing_TP: 3978 	Testing_FP: 3424
# 	Testing_TN: 1561 	Testing_FN: 1382
#
# GaussianNB  Testing Accuracy =  0.6
# 	Testing_Top_K_TP: 60 	Testing_Top_K_FP: 40
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-11-27 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5569373323579615
# 	Training_TP: 12109 	Training_FP: 10241
# 	Training_TN: 6163 	Training_FN: 4295
#
# GaussianNB  Testing Accuracy =  0.5087533666794921
# 	Testing_TP: 3469 	Testing_FP: 3186
# 	Testing_TN: 1820 	Testing_FN: 1921
#
# GaussianNB  Testing Accuracy =  0.63
# 	Testing_Top_K_TP: 63 	Testing_Top_K_FP: 37
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2013-12-27 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5586946079020055
# 	Training_TP: 3295 	Training_FP: 1340
# 	Training_TN: 15314 	Training_FN: 13359
#
# GaussianNB  Testing Accuracy =  0.6789880534082924
# 	Testing_TP: 659 	Testing_FP: 396
# 	Testing_TN: 4172 	Testing_FN: 1888
#
# GaussianNB  Testing Accuracy =  0.31
# 	Testing_Top_K_TP: 31 	Testing_Top_K_FP: 69
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-01-26 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5597725035546319
# 	Training_TP: 3866 	Training_FP: 2227
# 	Training_TN: 11488 	Training_FN: 9848
#
# GaussianNB  Testing Accuracy =  0.5743614613643712
# 	Testing_TP: 801 	Testing_FP: 582
# 	Testing_TN: 2752 	Testing_FN: 2051
#
# GaussianNB  Testing Accuracy =  0.65
# 	Testing_Top_K_TP: 65 	Testing_Top_K_FP: 35
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-02-25 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.594370155864066
# 	Training_TP: 5855 	Training_FP: 3639
# 	Training_TN: 8102 	Training_FN: 5886
#
# GaussianNB  Testing Accuracy =  0.5891012396694215
# 	Testing_TP: 1634 	Testing_FP: 1417
# 	Testing_TN: 2928 	Testing_FN: 1765
#
# GaussianNB  Testing Accuracy =  0.7
# 	Testing_Top_K_TP: 70 	Testing_Top_K_FP: 30
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-03-27 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5908041554444017
# 	Training_TP: 7007 	Training_FP: 5119
# 	Training_TN: 5277 	Training_FN: 3389
#
# GaussianNB  Testing Accuracy =  0.5933025677434624
# 	Testing_TP: 2960 	Testing_FP: 2101
# 	Testing_TN: 2054 	Testing_FN: 1336
#
# GaussianNB  Testing Accuracy =  0.69
# 	Testing_Top_K_TP: 69 	Testing_Top_K_FP: 31
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-04-26 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5883016653879135
# 	Training_TP: 5187 	Training_FP: 3231
# 	Training_TN: 7848 	Training_FN: 5891
#
# GaussianNB  Testing Accuracy =  0.5848512173128945
# 	Testing_TP: 1274 	Testing_FP: 903
# 	Testing_TN: 1969 	Testing_FN: 1399
#
# GaussianNB  Testing Accuracy =  0.68
# 	Testing_Top_K_TP: 68 	Testing_Top_K_FP: 32
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-05-26 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.587386798618243
# 	Training_TP: 4808 	Training_FP: 2936
# 	Training_TN: 7775 	Training_FN: 5903
#
# GaussianNB  Testing Accuracy =  0.5701837469217654
# 	Testing_TP: 1229 	Testing_FP: 760
# 	Testing_TN: 1781 	Testing_FN: 1509
#
# GaussianNB  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-06-25 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5714510050251256
# 	Training_TP: 2740 	Training_FP: 1375
# 	Training_TN: 8177 	Training_FN: 6812
#
# GaussianNB  Testing Accuracy =  0.524231934227607
# 	Testing_TP: 702 	Testing_FP: 303
# 	Testing_TN: 1721 	Testing_FN: 1896
#
# GaussianNB  Testing Accuracy =  0.77
# 	Testing_Top_K_TP: 77 	Testing_Top_K_FP: 23
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-07-25 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5580964970257766
# 	Training_TP: 1665 	Training_FP: 786
# 	Training_TN: 6779 	Training_FN: 5900
#
# GaussianNB  Testing Accuracy =  0.544256120527307
# 	Testing_TP: 639 	Testing_FP: 271
# 	Testing_TN: 2251 	Testing_FN: 2149
#
# GaussianNB  Testing Accuracy =  0.73
# 	Testing_Top_K_TP: 73 	Testing_Top_K_FP: 27
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-08-24 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5466807722824649
# 	Training_TP: 1302 	Training_FP: 596
# 	Training_TN: 6966 	Training_FN: 6260
#
# GaussianNB  Testing Accuracy =  0.5700442967884828
# 	Testing_TP: 996 	Testing_FP: 448
# 	Testing_TN: 7240 	Testing_FN: 5764
#
# GaussianNB  Testing Accuracy =  0.71
# 	Testing_Top_K_TP: 71 	Testing_Top_K_FP: 29
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-09-23 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5517525773195876
# 	Training_TP: 2600 	Training_FP: 1345
# 	Training_TN: 10780 	Training_FN: 9525
#
# GaussianNB  Testing Accuracy =  0.5501636326447126
# 	Testing_TP: 3862 	Testing_FP: 961
# 	Testing_TN: 6897 	Testing_FN: 7836
#
# GaussianNB  Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-10-23 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.6003517536704731
# 	Training_TP: 8000 	Training_FP: 4063
# 	Training_TN: 15553 	Training_FN: 11616
#
# GaussianNB  Testing Accuracy =  0.5656279508970727
# 	Testing_TP: 2812 	Testing_FP: 1212
# 	Testing_TN: 3777 	Testing_FN: 3848
#
# GaussianNB  Testing Accuracy =  0.69
# 	Testing_Top_K_TP: 69 	Testing_Top_K_FP: 31
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-11-22 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5944402804109167
# 	Training_TP: 8404 	Training_FP: 4120
# 	Training_TN: 18561 	Training_FN: 14277
#
# GaussianNB  Testing Accuracy =  0.5881798916882506
# 	Testing_TP: 1605 	Testing_FP: 989
# 	Testing_TN: 3391 	Testing_FN: 2509
#
# GaussianNB  Testing Accuracy =  0.55
# 	Testing_Top_K_TP: 55 	Testing_Top_K_FP: 45
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2014-12-22 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5850138711054204
# 	Training_TP: 5820 	Training_FP: 2633
# 	Training_TN: 16111 	Training_FN: 12924
#
# GaussianNB  Testing Accuracy =  0.6466246141457522
# 	Testing_TP: 746 	Testing_FP: 551
# 	Testing_TN: 4072 	Testing_FN: 2082
#
# GaussianNB  Testing Accuracy =  0.46
# 	Testing_Top_K_TP: 46 	Testing_Top_K_FP: 54
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-01-21 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5582590186795846
# 	Training_TP: 3495 	Training_FP: 1908
# 	Training_TN: 11717 	Training_FN: 10129
#
# GaussianNB  Testing Accuracy =  0.5881580674806354
# 	Testing_TP: 659 	Testing_FP: 635
# 	Testing_TN: 3821 	Testing_FN: 2502
#
# GaussianNB  Testing Accuracy =  0.19
# 	Testing_Top_K_TP: 19 	Testing_Top_K_FP: 81
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-02-20 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5553113553113553
# 	Training_TP: 3939 	Training_FP: 2656
# 	Training_TN: 8947 	Training_FN: 7663
#
# GaussianNB  Testing Accuracy =  0.5519959058341863
# 	Testing_TP: 1471 	Testing_FP: 1109
# 	Testing_TN: 3922 	Testing_FN: 3268
#
# GaussianNB  Testing Accuracy =  0.37
# 	Testing_Top_K_TP: 37 	Testing_Top_K_FP: 63
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-03-22 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.57387911060526
# 	Training_TP: 7214 	Training_FP: 5397
# 	Training_TN: 6904 	Training_FN: 5086
#
# GaussianNB  Testing Accuracy =  0.5684296939134514
# 	Testing_TP: 2779 	Testing_FP: 1627
# 	Testing_TN: 2068 	Testing_FN: 2053
#
# GaussianNB  Testing Accuracy =  0.69
# 	Testing_Top_K_TP: 69 	Testing_Top_K_FP: 31
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-04-21 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5267794495985032
# 	Training_TP: 10844 	Training_FP: 10157
# 	Training_TN: 2670 	Training_FN: 1983
#
# GaussianNB  Testing Accuracy =  0.4931581828133552
# 	Testing_TP: 2789 	Testing_FP: 2914
# 	Testing_TN: 815 	Testing_FN: 790
#
# GaussianNB  Testing Accuracy =  0.67
# 	Testing_Top_K_TP: 67 	Testing_Top_K_FP: 33
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-05-21 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5629763494932034
# 	Training_TP: 10428 	Training_FP: 8825
# 	Training_TN: 3902 	Training_FN: 2299
#
# GaussianNB  Testing Accuracy =  0.5522945570971185
# 	Testing_TP: 2198 	Testing_FP: 1862
# 	Testing_TN: 907 	Testing_FN: 655
#
# GaussianNB  Testing Accuracy =  0.71
# 	Testing_Top_K_TP: 71 	Testing_Top_K_FP: 29
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-06-20 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5999622516868778
# 	Training_TP: 7788 	Training_FP: 5670
# 	Training_TN: 4927 	Training_FN: 2808
#
# GaussianNB  Testing Accuracy =  0.6103173130450918
# 	Testing_TP: 2319 	Testing_FP: 1322
# 	Testing_TN: 970 	Testing_FN: 778
#
# GaussianNB  Testing Accuracy =  0.75
# 	Testing_Top_K_TP: 75 	Testing_Top_K_FP: 25
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-07-20 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.576538869356549
# 	Training_TP: 7272 	Training_FP: 5901
# 	Training_TN: 3059 	Training_FN: 1687
#
# GaussianNB  Testing Accuracy =  0.5266760620092611
# 	Testing_TP: 2032 	Testing_FP: 1972
# 	Testing_TN: 584 	Testing_FN: 379
#
# GaussianNB  Testing Accuracy =  0.55
# 	Testing_Top_K_TP: 55 	Testing_Top_K_FP: 45
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-08-19 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5540736995133051
# 	Training_TP: 6433 	Training_FP: 5578
# 	Training_TN: 2333 	Training_FN: 1477
#
# GaussianNB  Testing Accuracy =  0.4708711433756806
# 	Testing_TP: 3515 	Testing_FP: 5057
# 	Testing_TN: 1674 	Testing_FN: 774
#
# GaussianNB  Testing Accuracy =  0.41
# 	Testing_Top_K_TP: 41 	Testing_Top_K_FP: 59
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-09-18 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5755023293021505
# 	Training_TP: 4123 	Training_FP: 2519
# 	Training_TN: 8107 	Training_FN: 6502
#
# GaussianNB  Testing Accuracy =  0.5626637253550255
# 	Testing_TP: 3484 	Testing_FP: 1951
# 	Testing_TN: 8759 	Testing_FN: 7565
#
# GaussianNB  Testing Accuracy =  0.67
# 	Testing_Top_K_TP: 67 	Testing_Top_K_FP: 33
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-10-18 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5388313413014608
# 	Training_TP: 2379 	Training_FP: 917
# 	Training_TN: 17908 	Training_FN: 16446
#
# GaussianNB  Testing Accuracy =  0.5154785348562426
# 	Testing_TP: 788 	Testing_FP: 300
# 	Testing_TN: 5756 	Testing_FN: 5851
#
# GaussianNB  Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-11-17 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5385243369665946
# 	Training_TP: 2894 	Training_FP: 1148
# 	Training_TN: 21513 	Training_FN: 19767
#
# GaussianNB  Testing Accuracy =  0.5521726563252722
# 	Testing_TP: 859 	Testing_FP: 389
# 	Testing_TN: 4872 	Testing_FN: 4259
#
# GaussianNB  Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2015-12-17 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5368635899761878
# 	Training_TP: 2764 	Training_FP: 1139
# 	Training_TN: 20909 	Training_FN: 19283
#
# GaussianNB  Testing Accuracy =  0.5734167893961708
# 	Testing_TP: 1175 	Testing_FP: 401
# 	Testing_TN: 6612 	Testing_FN: 5392
#
# GaussianNB  Testing Accuracy =  0.83
# 	Testing_Top_K_TP: 83 	Testing_Top_K_FP: 17
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-01-16 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5471760160039462
# 	Training_TP: 2797 	Training_FP: 1076
# 	Training_TN: 17170 	Training_FN: 15448
#
# GaussianNB  Testing Accuracy =  0.5687291162576333
# 	Testing_TP: 554 	Testing_FP: 253
# 	Testing_TN: 4382 	Testing_FN: 3490
#
# GaussianNB  Testing Accuracy =  0.77
# 	Testing_Top_K_TP: 77 	Testing_Top_K_FP: 23
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-02-15 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5509370420031806
# 	Training_TP: 2517 	Training_FP: 884
# 	Training_TN: 15151 	Training_FN: 13517
#
# GaussianNB  Testing Accuracy =  0.5544071926728846
# 	Testing_TP: 697 	Testing_FP: 300
# 	Testing_TN: 5901 	Testing_FN: 5003
#
# GaussianNB  Testing Accuracy =  0.56
# 	Testing_Top_K_TP: 56 	Testing_Top_K_FP: 44
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-03-16 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5459198769157938
# 	Training_TP: 2312 	Training_FP: 760
# 	Training_TN: 16139 	Training_FN: 14587
#
# GaussianNB  Testing Accuracy =  0.5802298850574713
# 	Testing_TP: 928 	Testing_FP: 338
# 	Testing_TN: 7906 	Testing_FN: 6053
#
# GaussianNB  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-04-15 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5519301211608904
# 	Training_TP: 2957 	Training_FP: 1114
# 	Training_TN: 16631 	Training_FN: 14788
#
# GaussianNB  Testing Accuracy =  0.5417789757412399
# 	Testing_TP: 1007 	Testing_FP: 381
# 	Testing_TN: 5425 	Testing_FN: 5059
#
# GaussianNB  Testing Accuracy =  0.77
# 	Testing_Top_K_TP: 77 	Testing_Top_K_FP: 23
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-05-15 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5497680686205914
# 	Training_TP: 3039 	Training_FP: 1119
# 	Training_TN: 18176 	Training_FN: 16255
#
# GaussianNB  Testing Accuracy =  0.5294781736076267
# 	Testing_TP: 688 	Testing_FP: 234
# 	Testing_TN: 3533 	Testing_FN: 3517
#
# GaussianNB  Testing Accuracy =  0.73
# 	Testing_Top_K_TP: 73 	Testing_Top_K_FP: 27
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-06-14 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5546104215490554
# 	Training_TP: 2852 	Training_FP: 965
# 	Training_TN: 16317 	Training_FN: 14429
#
# GaussianNB  Testing Accuracy =  0.48464408725602753
# 	Testing_TP: 777 	Testing_FP: 160
# 	Testing_TN: 2600 	Testing_FN: 3431
#
# GaussianNB  Testing Accuracy =  0.9
# 	Testing_Top_K_TP: 90 	Testing_Top_K_FP: 10
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-07-14 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5685567203998046
# 	Training_TP: 3018 	Training_FP: 1194
# 	Training_TN: 12113 	Training_FN: 10288
#
# GaussianNB  Testing Accuracy =  0.5495364238410596
# 	Testing_TP: 922 	Testing_FP: 352
# 	Testing_TN: 3227 	Testing_FN: 3049
#
# GaussianNB  Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-08-13 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.558201177051979
# 	Training_TP: 2136 	Training_FP: 841
# 	Training_TN: 10289 	Training_FN: 8993
#
# GaussianNB  Testing Accuracy =  0.5471559839900784
# 	Testing_TP: 1122 	Testing_FP: 561
# 	Testing_TN: 8584 	Testing_FN: 7472
#
# GaussianNB  Testing Accuracy =  0.87
# 	Testing_Top_K_TP: 87 	Testing_Top_K_FP: 13
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-09-12 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.558329692278884
# 	Training_TP: 2988 	Training_FP: 1119
# 	Training_TN: 14902 	Training_FN: 13033
#
# GaussianNB  Testing Accuracy =  0.5621288171960611
# 	Testing_TP: 2617 	Testing_FP: 1055
# 	Testing_TN: 12054 	Testing_FN: 10373
#
# GaussianNB  Testing Accuracy =  0.9
# 	Testing_Top_K_TP: 90 	Testing_Top_K_FP: 10
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-10-12 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5614107153336072
# 	Training_TP: 5411 	Training_FP: 2272
# 	Training_TN: 23290 	Training_FN: 20150
#
# GaussianNB  Testing Accuracy =  0.5598114319387154
# 	Testing_TP: 1881 	Testing_FP: 753
# 	Testing_TN: 6669 	Testing_FN: 5970
#
# GaussianNB  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-11-11 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5725552854787442
# 	Training_TP: 8143 	Training_FP: 3875
# 	Training_TN: 25541 	Training_FN: 21272
#
# GaussianNB  Testing Accuracy =  0.595224823485693
# 	Testing_TP: 1638 	Testing_FP: 794
# 	Testing_TN: 4769 	Testing_FN: 3563
#
# GaussianNB  Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2016-12-11 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5757972231443692
# 	Training_TP: 7485 	Training_FP: 3604
# 	Training_TN: 22001 	Training_FN: 18119
#
# GaussianNB  Testing Accuracy =  0.6145461885218327
# 	Testing_TP: 1841 	Testing_FP: 1053
# 	Testing_TN: 7293 	Testing_FN: 4676
#
# GaussianNB  Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-01-10 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5716582566538043
# 	Training_TP: 5519 	Training_FP: 2622
# 	Training_TN: 17592 	Training_FN: 14695
#
# GaussianNB  Testing Accuracy =  0.6188709969241903
# 	Testing_TP: 1227 	Testing_FP: 794
# 	Testing_TN: 5614 	Testing_FN: 3419
#
# GaussianNB  Testing Accuracy =  0.78
# 	Testing_Top_K_TP: 78 	Testing_Top_K_FP: 22
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-02-09 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5712045341990866
# 	Training_TP: 3992 	Training_FP: 1404
# 	Training_TN: 16769 	Training_FN: 14181
#
# GaussianNB  Testing Accuracy =  0.5888665746203088
# 	Testing_TP: 1692 	Testing_FP: 750
# 	Testing_TN: 7691 	Testing_FN: 5801
#
# GaussianNB  Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-03-11 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5659767453080523
# 	Training_TP: 4185 	Training_FP: 1450
# 	Training_TN: 19277 	Training_FN: 16542
#
# GaussianNB  Testing Accuracy =  0.6125803077842522
# 	Testing_TP: 1233 	Testing_FP: 556
# 	Testing_TN: 6967 	Testing_FN: 4630
#
# GaussianNB  Testing Accuracy =  0.81
# 	Testing_Top_K_TP: 81 	Testing_Top_K_FP: 19
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-04-10 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5625498603909055
# 	Training_TP: 4064 	Training_FP: 1555
# 	Training_TN: 18501 	Training_FN: 15992
#
# GaussianNB  Testing Accuracy =  0.5458376511226252
# 	Testing_TP: 1170 	Testing_FP: 493
# 	Testing_TN: 6731 	Testing_FN: 6081
#
# GaussianNB  Testing Accuracy =  0.82
# 	Testing_Top_K_TP: 82 	Testing_Top_K_FP: 18
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-05-10 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5640562388529868
# 	Training_TP: 4338 	Training_FP: 1768
# 	Training_TN: 20014 	Training_FN: 17053
#
# GaussianNB  Testing Accuracy =  0.5647312269183422
# 	Testing_TP: 955 	Testing_FP: 378
# 	Testing_TN: 4550 	Testing_FN: 3865
#
# GaussianNB  Testing Accuracy =  0.88
# 	Testing_Top_K_TP: 88 	Testing_Top_K_FP: 12
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-06-09 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5637169329931516
# 	Training_TP: 3370 	Training_FP: 1264
# 	Training_TN: 17620 	Training_FN: 14981
#
# GaussianNB  Testing Accuracy =  0.4655563108996148
# 	Testing_TP: 920 	Testing_FP: 200
# 	Testing_TN: 3189 	Testing_FN: 4517
#
# GaussianNB  Testing Accuracy =  0.95
# 	Testing_Top_K_TP: 95 	Testing_Top_K_FP: 5
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-07-09 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5643656139917187
# 	Training_TP: 3507 	Training_FP: 1424
# 	Training_TN: 14757 	Training_FN: 12674
#
# GaussianNB  Testing Accuracy =  0.5016193208105857
# 	Testing_TP: 1224 	Testing_FP: 418
# 	Testing_TN: 4197 	Testing_FN: 4968
#
# GaussianNB  Testing Accuracy =  0.89
# 	Testing_Top_K_TP: 89 	Testing_Top_K_FP: 11
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-08-08 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5696561257992051
# 	Training_TP: 3333 	Training_FP: 1318
# 	Training_TN: 13150 	Training_FN: 11134
#
# GaussianNB  Testing Accuracy =  0.6044930995122964
# 	Testing_TP: 1813 	Testing_FP: 899
# 	Testing_TN: 9838 	Testing_FN: 6724
#
# GaussianNB  Testing Accuracy =  0.86
# 	Testing_Top_K_TP: 86 	Testing_Top_K_FP: 14
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-09-07 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5649562470874541
# 	Training_TP: 4221 	Training_FP: 1712
# 	Training_TN: 17601 	Training_FN: 15092
#
# GaussianNB  Testing Accuracy =  0.5864356660853742
# 	Testing_TP: 3134 	Testing_FP: 1353
# 	Testing_TN: 12335 	Testing_FN: 9556
#
# GaussianNB  Testing Accuracy =  0.81
# 	Testing_Top_K_TP: 81 	Testing_Top_K_FP: 19
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-10-07 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5786918480580452
# 	Training_TP: 7698 	Training_FP: 3273
# 	Training_TN: 24843 	Training_FN: 20418
#
# GaussianNB  Testing Accuracy =  0.5604621789774056
# 	Testing_TP: 3132 	Testing_FP: 1306
# 	Testing_TN: 8849 	Testing_FN: 8090
#
# GaussianNB  Testing Accuracy =  0.92
# 	Testing_Top_K_TP: 92 	Testing_Top_K_FP: 8
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-11-06 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5790175428083474
# 	Training_TP: 9166 	Training_FP: 3892
# 	Training_TN: 29484 	Training_FN: 24209
#
# GaussianNB  Testing Accuracy =  0.5619002173797784
# 	Testing_TP: 2490 	Testing_FP: 1093
# 	Testing_TN: 8108 	Testing_FN: 7170
#
# GaussianNB  Testing Accuracy =  0.8
# 	Testing_Top_K_TP: 80 	Testing_Top_K_FP: 20
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2017-12-06 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5899946699154801
# 	Training_TP: 11678 	Training_FP: 5769
# 	Training_TN: 27064 	Training_FN: 21154
#
# GaussianNB  Testing Accuracy =  0.582629188940622
# 	Testing_TP: 3158 	Testing_FP: 1652
# 	Testing_TN: 6978 	Testing_FN: 5609
#
# GaussianNB  Testing Accuracy =  0.88
# 	Testing_Top_K_TP: 88 	Testing_Top_K_FP: 12
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-01-05 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5785640504910801
# 	Training_TP: 8706 	Training_FP: 4219
# 	Training_TN: 24341 	Training_FN: 19853
#
# GaussianNB  Testing Accuracy =  0.640347563279184
# 	Testing_TP: 1873 	Testing_FP: 1035
# 	Testing_TN: 6602 	Testing_FN: 3725
#
# GaussianNB  Testing Accuracy =  0.84
# 	Testing_Top_K_TP: 84 	Testing_Top_K_FP: 16
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-02-04 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.570555032925682
# 	Training_TP: 6136 	Training_FP: 2686
# 	Training_TN: 21763 	Training_FN: 18313
#
# GaussianNB  Testing Accuracy =  0.5914665423175566
# 	Testing_TP: 2282 	Testing_FP: 1144
# 	Testing_TN: 10402 	Testing_FN: 7617
#
# GaussianNB  Testing Accuracy =  0.85
# 	Testing_Top_K_TP: 85 	Testing_Top_K_FP: 15
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-03-06 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5530389630519443
# 	Training_TP: 4609 	Training_FP: 1872
# 	Training_TN: 23935 	Training_FN: 21197
#
# GaussianNB  Testing Accuracy =  0.5693199433847813
# 	Testing_TP: 1164 	Testing_FP: 484
# 	Testing_TN: 7283 	Testing_FN: 5906
#
# GaussianNB  Testing Accuracy =  0.83
# 	Testing_Top_K_TP: 83 	Testing_Top_K_FP: 17
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0
#
# As of Date: 2018-04-05 00:00:00
# =====================================================================================
# GaussianNB  Testing Accuracy =  0.5578371959708459
# 	Training_TP: 4432 	Training_FP: 1780
# 	Training_TN: 22815 	Training_FN: 19817
#
# GaussianNB  Testing Accuracy =  0.46345987920621223
# 	Testing_TP: 3031 	Testing_FP: 553
# 	Testing_TN: 7712 	Testing_FN: 11884
#
# GaussianNB  Testing Accuracy =  0.93
# 	Testing_Top_K_TP: 93 	Testing_Top_K_FP: 7
# 	Testing_Top_K_TN: 0 	Testing_Top_K_FN: 0

# %%
# Model_variables_con= ["Project Cost","Number of dates since posted","School Percentage Free Lunch","Project Cost"]
# Model_variables_cat= ["School Metro Type","Teacher Prefix","Project Grade Level Category"]

# clf = tree.DecisionTreeClassifier( criterion='entropy')
# Output,Test_Data_Final,Train_Data_Final= Train_Model(clf, Model_variables_con,Model_variables_cat,
#                                     Data,Time_period_indays=30,K=100,Fund_Ratio_treshold=0.03)

# %%
Output.keys()
# Out:
# dict_keys(['Overall_Training_Accuracy', 'Overall_Training_Precision', 'Overall_Training_Recall', 'Overall_Testing_Accuracy', 'Overall_Testing_Precision', 'Overall_Testing_Recall', 'Top_K_Accuracy', 'Top_K_Precision', 'Top_K_Recall', 'Classifier', 'Model_variables', 'Time_points'])

# %%
X_test = Test_Data_Final.loc[:,Output["Model_variables"]]
Y_test = np.array(Test_Data_Final.loc[:,["Label"]])[:,0]

disp = plot_precision_recall_curve(Output["Classifier"], X_test, Y_test)
disp.ax_.set_title('Precision-Recall curve')
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve')

# %%
n_cols=3
n_rows=3
fig, axs=plt.subplots(n_rows,n_cols,figsize=(n_cols*6,n_rows*4))

ax = axs[0][0]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Accuracy",fontsize=15);

ax = axs[0][1]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Precision",fontsize=15);

ax = axs[0][2]
sns.lineplot(data=Output, x="Time_points", y="Overall_Training_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Training_Recall",fontsize=15);

ax = axs[1][0]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Accuracy",fontsize=15);

ax = axs[1][1]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Precision",fontsize=15);

ax = axs[1][2]
sns.lineplot(data=Output, x="Time_points", y="Overall_Testing_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Overall_Testing_Recall",fontsize=15);

ax = axs[2][0]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Accuracy",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Accuracy",fontsize=15);

ax = axs[2][1]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Precision",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Precision",fontsize=15);

ax = axs[2][2]
sns.lineplot(data=Output, x="Time_points", y="Top_K_Recall",ax=ax)
ax.set_xlabel("Time in years",fontsize=15);
ax.set_ylabel("Top_K_Recall",fontsize=15);

# %%
prT=[]
reT=[]
t=[]
k=2
Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
Test_Data_Final['Y_pred']=0
while (k<=100):
    Test_Data_Final.loc[Test_Data_Final.head(int(len(Test_Data_Final)*k/100)).index,'Y_pred'] = 1
    
    Y_test_k =  Test_Data_Final.loc[:,["Label"]] 
    Y_pred_k =  Test_Data_Final.loc[:,["Y_pred"]] 

    cm= confusion_matrix(Y_test_k,Y_pred_k)
    if len(cm.ravel())==4:TN, FP ,FN, TP =  cm.ravel()
    else: TN, FP ,FN, TP=0,0,0,100
    t+=[k]
#     print(len(Y_test_k[Y_test_k["Label"]==1])/len(Tk))
    preci=TP/(TP+FP)
    prT+=[preci]
    rec=TP/(TP+FN)
    reT+=[rec]
    k+=2
ax1=plt.plot(t,prT, 'r',label='Precision')
ax2=plt.plot(t,reT, 'b',label='Recall')
plt.xlabel("Top K as a persentage")

plt.title(Output["Classifier"].__class__.__name__+" precision and recall for different K values")
plt.legend()
plt.show()

# %%
prT=[]
reT=[]
t=[]
k=2
Test_Data_Final=Test_Data_Final.sort_values(by=['Y_pred_prob'], ascending=False)
while (k<=100):
    Tk=Test_Data_Final.head(int(len(Test_Data_Final)*k/100))
    Y_test_k =  Tk.loc[:,["Label"]] 
    Y_pred_k =  Tk.loc[:,["Y_pred"]] 
    cm= confusion_matrix(Y_test_k,Y_pred_k)
    if len(cm.ravel())==4:TN, FP ,FN, TP =  cm.ravel()
    else: TN, FP ,FN, TP=0,0,0,100
    t+=[k]
#     print(len(Y_test_k[Y_test_k["Label"]==1])/len(Tk))
    preci=TP/(TP+FP)
    prT+=[preci]
    rec=TP/(TP+FN)
    reT+=[rec]
    k+=2
ax1=plt.plot(t,prT, 'r',label='Precision')
ax2=plt.plot(t,reT, 'b',label='Recall')
plt.xlabel("Top K as a persentage")

plt.title(Output["Classifier"].__class__.__name__+" precision and recall for different K values")
plt.legend()
plt.show()

# %%
import lime
import lime.lime_tabular

X_train = Train_Data_Final.loc[:,Output["Model_variables"]]

explainer = lime.lime_tabular.LimeTabularExplainer(np.array(X_train),
                    feature_names=Output["Model_variables"], 
                    class_names=['Label'], 
                    # categorical_features=, n
                    # There is no categorical features in this example, otherwise specify them.                               
                    verbose=True, mode='regression')

explainer

# %%
exp = explainer.explain_instance(X_test.iloc[-1], Output["Classifier"].predict)
exp.as_pyplot_figure()
# Out:
# Intercept 1.5540497686548347
# Prediction_local [0.01750716]
# Right: 0

# %%
exp.show_in_notebook(show_table=True, show_all=False)
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %%
exp = explainer.explain_instance(X_test.iloc[0], Output["Classifier"].predict)
exp.as_pyplot_figure()
# Out:
# Intercept 1.0311437656717402
# Prediction_local [1.22111353]
# Right: 1

# %%
exp.show_in_notebook(show_table=True, show_all=False)
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %%
import shap
explainer = shap.TreeExplainer(Output["Classifier"])
X_train = Train_Data_Final.loc[:,Output["Model_variables"]]
shap_values = explainer.shap_values(X_train)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-1ce550c5bd9a> in <module>
#       1 import shap
# ----> 2 explainer = shap.TreeExplainer(Output["Classifier"])
#       3 X_train = Train_Data_Final.loc[:,Output["Model_variables"]]
#       4 shap_values = explainer.shap_values(X_train)
#
# ~\.conda\envs\Laptop\lib\site-packages\shap\explainers\_tree.py in __init__(self, model, data, model_output, feature_perturbation, **deprecated_options)
#     134         self.feature_perturbation = feature_perturbation
#     135         self.expected_value = None
# --> 136         self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     137         self.model_output = model_output
#     138         #self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#
# ~\.conda\envs\Laptop\lib\site-packages\shap\explainers\_tree.py in __init__(self, model, data, data_missing, model_output)
#     943             self.base_offset = model.init_params[param_idx]
#     944         else:
# --> 945             raise Exception("Model type not yet supported by TreeExplainer: " + str(type(model)))
#     946
#     947         # build a dense numpy version of all the tree objects
#
# Exception: Model type not yet supported by TreeExplainer: <class 'sklearn.naive_bayes.GaussianNB'>
